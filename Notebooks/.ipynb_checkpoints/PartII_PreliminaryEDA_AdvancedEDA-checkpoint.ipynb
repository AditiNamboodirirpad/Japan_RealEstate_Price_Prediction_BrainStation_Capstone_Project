# %% [markdown]
# This notebook is the second notebook. It contains familiarization of Pre-owned Condominiums,etc real estate data of Japan. Data quality issues, feature engineering opportunities and any other notable observations regarding data preprocessing that was done previously has been **re-explored and changed**. In addition, Exploratory Data Analysis (EDA) has been conducted to describe relationships between different variables and Trade price.
#
# **Author: Aditi Namboodiripad**
#
# **Date: 19/9/2023**

# %% [markdown]
# # Real estate dataset of Pre-owned Condominiums and others

# %% [markdown]
# ## Table Of Contents
#
# 1. [Data Dictionary](#Data-Dictionary) <br>
# 2. [Basic Analysis](#Basic-Analysis) <br>
# 3. [Dealing with nulls](#Dealing-with-nulls)<br>
# 4. [Dealing with Duplicates](#Dealing-with-Duplicates)<br>
# 5. [Further Data Cleaning](#Further-Data-Cleaning)<br>
# 6. [Analyzing Patterns](#Analyzing-Patterns)<br>
# 7. [Summary](#Summary)<br>

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# 1. **Type:** Real Estate Type (e.g., Residential Land, Agricultural Land, Condominiums).
# 2. **Region:** Characteristics of surrounding areas (e.g., Residential Area, Commercial Area).
# 3. **MunicipalityCode:** City code of Japan.
# 4. **Prefecture:** Prefecture name of Japan.
# 5. **Municipality:** City name.
# 6. **DistrictName:** District name.
# 7. **NearestStation:** Nearest station name.
# 8. **TimeToNearestStation:** Time to the nearest station (in minutes).
# 9. **TradePrice:** Transaction prices in Japanese Yen.
# 10. **FloorPlan:** Property floor plan (e.g., 3LDK, 2DK).
# 11. **Area:** Surveyed area in square meters.
# 12. **UnitPrice:** Unit Land Price (Yen) per square meter.
# 13. **PricePerTsubo:** Unit Land Price (Yen) per Tsubo.
# 14. **Frontage:** Frontage in meters.
# 15. **BuildingYear:** Construction year of the building.
# 16. **PrewarBuilding:** Buildings built before 1945.
# 17. **Structure:** Building structure (e.g., Steel frame reinforced concrete, Wooden).
# 18. **Use:** Current property usage (e.g., House, Office, Factory).
# 19. **Purpose:** Purpose of future use (e.g., House, Shop, Office).
# 20. **Direction:** Frontage road direction.
# 21. **Classification:** Frontage road classification (e.g., City Road, National Highway).
# 22. **Breadth:** Frontage road breadth in meters.
# 23. **CityPlanning:** Use districts designated by the City Planning Act.
# 24. **CoverageRatio:** Maximum Building Coverage Ratio (%).
# 25. **FloorAreaRatio:** Maximum Floor-area Ratio (%).
# 26. **Period:** Time of transaction.
# 27. **Year:** Time of transaction year.
# 28. **Quarter:** Time of transaction year-quarter.
# 29. **Renovation:** Renovation status.
# 30. **Remarks:** Additional notes and remarks.

# %% [markdown]
# # Basic Analysis

# %% [markdown]
# Import all libraries

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import FuncFormatter
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import mean_squared_error
from scipy.stats import kruskal
import scikit_posthocs as sp
from scipy.stats import f_oneway
from scipy import stats
import random
from scipy.stats import chi2_contingency
#from sklearn.ensemble import RandomForestRegressor
#from sklearn.preprocessing import StandardScaler
#from sklearn.metrics import r2_score

# %% [markdown]
# Reading the csv and setting max columns and rows that are to be displayed

# %%
df=pd.read_csv("Data/Pre-owned Condominiums, etc..csv")
pd.options.display.max_columns=4000
pd.options.display.max_rows = 999

# %% [markdown]
# Now lets check the first and last few rows

# %%
df.head()
# Out:
#    No                RealEstateType  SurroundingArea  CityCode PrefectureName  \
# 0   3  Pre-owned Condominiums, etc.              NaN      1101       Hokkaido
# 1  10  Pre-owned Condominiums, etc.              NaN      1101       Hokkaido
# 2  14  Pre-owned Condominiums, etc.              NaN      1101       Hokkaido
# 3  20  Pre-owned Condominiums, etc.              NaN      1101       Hokkaido
# 4  25  Pre-owned Condominiums, etc.              NaN      1101       Hokkaido
#
#                  CityName DistrictName NearestStation  \
# 0  Chuo Ward,Sapporo City   Asahigaoka   Maruyamakoen
# 1  Chuo Ward,Sapporo City   Asahigaoka   Maruyamakoen
# 2  Chuo Ward,Sapporo City   Asahigaoka   Maruyamakoen
# 3  Chuo Ward,Sapporo City   Asahigaoka   Maruyamakoen
# 4  Chuo Ward,Sapporo City   Asahigaoka   Maruyamakoen
#
#   TimeToNearestStationOriginal  MinTimeToNearestStation  \
# 0                           20                     20.0
# 1                           23                     23.0
# 2                           25                     25.0
# 3                          NaN                      NaN
# 4                            0                      0.0
#
#    MaxTimeToNearestStation  TradePriceYen FloorPlan  SurveyedAreaM2  \
# 0                     20.0       19000000      4LDK              95
# 1                     23.0       14000000      4LDK              90
# 2                     25.0       27000000      2LDK              80
# 3                      NaN       30000000      4LDK             120
# 4                      0.0       19000000      4LDK              95
#
#    AreaIsGreaterFlag  UnitLandPricePerM2Yen  UnitLandPricePerTsuboYen  \
# 0                  0                    NaN                       NaN
# 1                  0                    NaN                       NaN
# 2                  0                    NaN                       NaN
# 3                  0                    NaN                       NaN
# 4                  0                    NaN                       NaN
#
#    LandShape  FrontageM  FrontageIsGreaterFlag  TotalFloorAreaM2  \
# 0        NaN        NaN                  False               NaN
# 1        NaN        NaN                  False               NaN
# 2        NaN        NaN                  False               NaN
# 3        NaN        NaN                  False               NaN
# 4        NaN        NaN                  False               NaN
#
#    TotalFloorAreaIsGreaterFlag  ConstructionYear  PrewarBuildingFlag  \
# 0                            0            1997.0                   0
# 1                            0            1989.0                   0
# 2                            0            2002.0                   0
# 3                            0            2002.0                   0
# 4                            0            1997.0                   0
#
#   BuildingStructure CurrentUsage FutureUsePurpose  FrontageRoadDirection  \
# 0                RC          NaN            House                    NaN
# 1                RC        House            House                    NaN
# 2                RC        House              NaN                    NaN
# 3               NaN        House              NaN                    NaN
# 4                RC        House              NaN                    NaN
#
#    FrontageRoadClassification  FrontageRoadBreadthM  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
#
#                                 CityPlanningCategory  \
# 0                       Neighborhood Commercial Zone
# 1  Category I Exclusively Low-story Residential Zone
# 2                        Category I Residential Zone
# 3                        Category I Residential Zone
# 4                                                NaN
#
#    MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 0                             80.0                     200.0
# 1                             40.0                      80.0
# 2                             60.0                     200.0
# 3                             60.0                     200.0
# 4                              NaN                       NaN
#
#   TransactionPeriod  TransactionYear  TransactionYearQuarter RenovationStatus  \
# 0  4th quarter 2018             2018                       4          Not yet
# 1  4th quarter 2017             2017                       4          Not yet
# 2  2nd quarter 2010             2010                       2          Not yet
# 3  3rd quarter 2006             2006                       3          Not yet
# 4  1st quarter 2011             2011                       1          Not yet
#
#   Notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df.tail()
# Out:
#            No                RealEstateType  SurroundingArea  CityCode  \
# 617854  29892  Pre-owned Condominiums, etc.              NaN     47211
# 617855  29921  Pre-owned Condominiums, etc.              NaN     47211
# 617856  29959  Pre-owned Condominiums, etc.              NaN     47211
# 617857  29997  Pre-owned Condominiums, etc.              NaN     47211
# 617858  30381  Pre-owned Condominiums, etc.              NaN     47213
#
#             PrefectureName      CityName  DistrictName NearestStation  \
# 617854  Okinawa Prefecture  Okinawa City        Tobaru            NaN
# 617855  Okinawa Prefecture  Okinawa City   Aza Hiyagon            NaN
# 617856  Okinawa Prefecture  Okinawa City      Miyazato            NaN
# 617857  Okinawa Prefecture  Okinawa City      Yamazato            NaN
# 617858  Okinawa Prefecture    Uruma City  Aza Kawasaki            NaN
#
#        TimeToNearestStationOriginal  MinTimeToNearestStation  \
# 617854                          NaN                      NaN
# 617855                          NaN                      NaN
# 617856                          NaN                      NaN
# 617857                          NaN                      NaN
# 617858                          NaN                      NaN
#
#         MaxTimeToNearestStation  TradePriceYen FloorPlan  SurveyedAreaM2  \
# 617854                      NaN        5800000      3LDK              80
# 617855                      NaN        5000000      3LDK              60
# 617856                      NaN        6500000      4LDK              85
# 617857                      NaN        7000000       3DK              55
# 617858                      NaN        4900000      2LDK              60
#
#         AreaIsGreaterFlag  UnitLandPricePerM2Yen  UnitLandPricePerTsuboYen  \
# 617854                  0                    NaN                       NaN
# 617855                  0                    NaN                       NaN
# 617856                  0                    NaN                       NaN
# 617857                  0                    NaN                       NaN
# 617858                  0                    NaN                       NaN
#
#         LandShape  FrontageM  FrontageIsGreaterFlag  TotalFloorAreaM2  \
# 617854        NaN        NaN                  False               NaN
# 617855        NaN        NaN                  False               NaN
# 617856        NaN        NaN                  False               NaN
# 617857        NaN        NaN                  False               NaN
# 617858        NaN        NaN                  False               NaN
#
#         TotalFloorAreaIsGreaterFlag  ConstructionYear  PrewarBuildingFlag  \
# 617854                            0            1985.0                   0
# 617855                            0            1984.0                   0
# 617856                            0            2001.0                   0
# 617857                            0            1991.0                   0
# 617858                            0            1986.0                   0
#
#        BuildingStructure CurrentUsage FutureUsePurpose  FrontageRoadDirection  \
# 617854                RC        House              NaN                    NaN
# 617855                RC        House              NaN                    NaN
# 617856                RC        House              NaN                    NaN
# 617857                RC        House              NaN                    NaN
# 617858                RC        House              NaN                    NaN
#
#         FrontageRoadClassification  FrontageRoadBreadthM  \
# 617854                         NaN                   NaN
# 617855                         NaN                   NaN
# 617856                         NaN                   NaN
# 617857                         NaN                   NaN
# 617858                         NaN                   NaN
#
#                   CityPlanningCategory  MaxBuildingCoverageRatioPercent  \
# 617854  Non-divided City Planning Area                              NaN
# 617855  Non-divided City Planning Area                             70.0
# 617856  Non-divided City Planning Area                             70.0
# 617857    Neighborhood Commercial Zone                             80.0
# 617858  Non-divided City Planning Area                             60.0
#
#         MaxFloorAreaRatioPercent TransactionPeriod  TransactionYear  \
# 617854                       NaN  2nd quarter 2008             2008
# 617855                     200.0  3rd quarter 2006             2006
# 617856                     200.0  4th quarter 2008             2008
# 617857                     300.0  1st quarter 2008             2008
# 617858                     200.0  4th quarter 2007             2007
#
#         TransactionYearQuarter RenovationStatus  \
# 617854                       2          Not yet
# 617855                       3          Not yet
# 617856                       4          Not yet
# 617857                       1          Not yet
# 617858                       4          Not yet
#
#                                                     Notes
# 617854                                                NaN
# 617855                                                NaN
# 617856  Dealings in which auction or arbiter participates
# 617857  Dealings in which auction or arbiter participates
# 617858  Dealings in which auction or arbiter participates

# %% [markdown]
# Let us check a sample of rows

# %%
df.sample(50)
# Out:
#             No                RealEstateType  SurroundingArea  CityCode  \
# 591363   66896  Pre-owned Condominiums, etc.              NaN     40106
# 108779  150669  Pre-owned Condominiums, etc.              NaN     12220
# 380518  258154  Pre-owned Condominiums, etc.              NaN     14135
# 45205    13060  Pre-owned Condominiums, etc.              NaN     11101
# 320772   59765  Pre-owned Condominiums, etc.              NaN     14116
# 554297  146554  Pre-owned Condominiums, etc.              NaN     28111
# 447559   67182  Pre-owned Condominiums, etc.              NaN     26104
# 508217  190960  Pre-owned Condominiums, etc.              NaN     27103
# 483395   87687  Pre-owned Condominiums, etc.              NaN     27127
# 447476   66985  Pre-owned Condominiums, etc.              NaN     26104
# 117238    6212  Pre-owned Condominiums, etc.              NaN     13102
# 310793   30789  Pre-owned Condominiums, etc.              NaN     14109
# 91558    46265  Pre-owned Condominiums, etc.              NaN     12204
# 98576    79952  Pre-owned Condominiums, etc.              NaN     12217
# 268334  299019  Pre-owned Condominiums, etc.              NaN     13121
# 582816   17625  Pre-owned Condominiums, etc.              NaN     40133
# 174063   87074  Pre-owned Condominiums, etc.              NaN     13111
# 430878   27961  Pre-owned Condominiums, etc.              NaN     24202
# 249899  246577  Pre-owned Condominiums, etc.              NaN     13119
# 568128   35236  Pre-owned Condominiums, etc.              NaN     34101
# 49467    31745  Pre-owned Condominiums, etc.              NaN     11201
# 600632   99810  Pre-owned Condominiums, etc.              NaN     40218
# 564827   30718  Pre-owned Condominiums, etc.              NaN     33101
# 499652  151698  Pre-owned Condominiums, etc.              NaN     27205
# 1540      2259  Pre-owned Condominiums, etc.              NaN      1101
# 104645  119249  Pre-owned Condominiums, etc.              NaN     12227
# 43767     7364  Pre-owned Condominiums, etc.              NaN     11104
# 264813  289558  Pre-owned Condominiums, etc.              NaN     13207
# 53820    50370  Pre-owned Condominiums, etc.              NaN     11108
# 223588  182181  Pre-owned Condominiums, etc.              NaN     13119
# 204263  143151  Pre-owned Condominiums, etc.              NaN     13115
# 260871  278573  Pre-owned Condominiums, etc.              NaN     13205
# 27479    14546  Pre-owned Condominiums, etc.              NaN      4103
# 478902   72385  Pre-owned Condominiums, etc.              NaN     27209
# 31400    32714  Pre-owned Condominiums, etc.              NaN      4102
# 508217                            4                      4.0
# 483395                            5                      5.0
# 447476                            5                      5.0
# 117238                            3                      3.0
# 310793                           14                     14.0
# 91558                            12                     12.0
# 98576                             3                      3.0
# 268334                            7                      7.0
# 582816                           11                     11.0
# 174063                           13                     13.0
# 430878                           11                     11.0
# 249899                            7                      7.0
# 568128                 30-60minutes                     30.0
# 49467                            24                     24.0
# 600632                           18                     18.0
# 564827                            9                      9.0
# 499652                           16                     16.0
# 1540                              6                      6.0
# 104645                           24                     24.0
# 43767                             2                      2.0
# 264813                            3                      3.0
# 53820                            15                     15.0
# 223588                            9                      9.0
# 204263                            5                      5.0
# 260871                           14                     14.0
# 27479                             7                      7.0
# 478902                            5                      5.0
# 31400                             7                      7.0
# 27955                             3                      3.0
# 509221                            5                      5.0
# 382742                           10                     10.0
# 76304                            16                     16.0
# 105832                           14                     14.0
# 222762                            7                      7.0
# 109041                            6                      6.0
# 613470                           18                     18.0
# 323802                            8                      8.0
# 114665                            2                      2.0
# 490192                            8                      8.0
# 171459                          NaN                      NaN
# 95676                             6                      6.0
# 322106                           14                     14.0
# 491207                            3                      3.0
#
#         MaxTimeToNearestStation  TradePriceYen FloorPlan  SurveyedAreaM2  \
# 591363                      8.0        1800000        1K              20
# 108779                     11.0       19000000      3LDK              70
# 380518                     13.0        7000000       2DK              30
# 45205                       NaN       13000000      3LDK              70
# 320772                      2.0       40000000      3LDK              75
# 554297                     60.0        9400000      3LDK              70
# 447559                      NaN       61000000      3LDK             110
# 508217                      4.0       24000000      3LDK              60
# 483395                      5.0       52000000      3LDK              85
# 447476                      5.0       22000000      3LDK              55
# 117238                      3.0       30000000       1DK              40
# 310793                     14.0       51000000      3LDK              70
# 91558                      12.0       33000000      2LDK              75
# 98576                       3.0        2000000        1K              15
# 268334                      7.0       13000000        1K              20
# 582816                     11.0       12000000       1DK              20
# 174063                     13.0       23000000       3DK              45
# 430878                     11.0       14000000      4LDK              75
# 249899                      7.0       22000000       3DK              50
# 568128                     60.0       22000000      4LDK              75
# 49467                      24.0        4800000      2LDK              50
# 600632                     18.0        9000000      4LDK              90
# 564827                      9.0       18000000       NaN              60
# 499652                     16.0       20000000      3LDK              70
# 1540                        6.0       26000000      3LDK              75
# 104645                     24.0       64000000      3LDK             105
# 43767                       2.0       22000000      3LDK              60
# 264813                      3.0       23000000      3LDK              65
# 53820                      15.0       30000000      4LDK              80
# 223588                      9.0        5000000        1K              20
# 204263                      5.0       48000000      3LDK              70
# 260871                     14.0       10000000      2LDK              55
# 27479                       7.0        5900000       1DK              25
# 478902                      5.0       29000000      3LDK              70
# 31400                       7.0       12000000      3LDK              70
# 27955                       3.0        7500000      3LDK              65
# 509221                      5.0        2500000      3LDK              60
# 382742                     10.0       30000000      4LDK              80
# 76304                      16.0       28000000      3LDK              65
# 105832                     14.0       30000000      3LDK              80
# 222762                      7.0       24000000        1K              25
# 109041                      6.0       16000000    3LDK+S              80
# 613470                     18.0       18000000      4LDK              80
# 323802                      8.0       27000000      1LDK              50
# 76304                          NaN                   NaN
# 105832                         NaN                   NaN
# 222762                         NaN                   NaN
# 109041                         NaN                   NaN
# 613470                         NaN                   NaN
# 323802                         NaN                   NaN
# 114665                         NaN                   NaN
# 490192                         NaN                   NaN
# 171459                         NaN                   NaN
# 95676                          NaN                   NaN
# 322106                         NaN                   NaN
# 491207                         NaN                   NaN
#
#                                      CityPlanningCategory  \
# 591363                                    Commercial Zone
# 108779                        Category I Residential Zone
# 380518                        Category I Residential Zone
# 45205                                                 NaN
# 320772                       Neighborhood Commercial Zone
# 554297  Category I Exclusively Medium-high Residential...
# 447559                                    Commercial Zone
# 508217                                    Commercial Zone
# 483395                                    Commercial Zone
# 447476                       Neighborhood Commercial Zone
# 117238                                    Commercial Zone
# 310793  Category I Exclusively Medium-high Residential...
# 91558                                                 NaN
# 98576                         Category I Residential Zone
# 268334                              Quasi-industrial Zone
# 582816                                    Commercial Zone
# 174063                       Neighborhood Commercial Zone
# 430878                       Neighborhood Commercial Zone
# 249899                                    Commercial Zone
# 568128                                    Commercial Zone
# 49467                               Quasi-industrial Zone
# 600632  Category I Exclusively Medium-high Residential...
# 564827                                    Commercial Zone
# 499652  Category I Exclusively Medium-high Residential...
# 1540                                      Commercial Zone
# 104645                       Category II Residential Zone
# 43767                        Neighborhood Commercial Zone
# 264813                       Neighborhood Commercial Zone
# 53820   Category II Exclusively Medium-high Residentia...
# 223588                              Quasi-industrial Zone
# 204263                             Quasi-residential Zone
# 260871                        Category I Residential Zone
# 27479                                     Commercial Zone
# 478902                       Category II Residential Zone
# 31400                               Quasi-industrial Zone
# 27955                                     Commercial Zone
# 509221                       Neighborhood Commercial Zone
# 382742                        Category I Residential Zone
# 76304                         Category I Residential Zone
# 105832                        Category I Residential Zone
# 222762                        Category I Residential Zone
# 109041  Category I Exclusively Low-story Residential Zone
# 613470                                                NaN
# 323802                                    Commercial Zone
# 114665                                    Commercial Zone
# 490192                        Category I Residential Zone
# 171459                        Category I Residential Zone
# 95676                         Category I Residential Zone
# 322106                              Quasi-industrial Zone
# 491207                                    Commercial Zone
#
#         MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 591363                             80.0                     400.0
# 108779                             60.0                     200.0
# 380518                             60.0                     200.0
# 45205                               NaN                       NaN
# 320772                             80.0                     300.0
# 554297                             60.0                     200.0
# 447559                             80.0                     400.0
# 508217                              NaN                       NaN
# 483395                             80.0                     600.0
# 447476                             80.0                     300.0
# 117238                             80.0                     700.0
# 310793                             60.0                     150.0
# 91558                               NaN                       NaN
# 98576                              60.0                     200.0
# 268334                             60.0                     400.0
# 582816                             80.0                     400.0
# 174063                             80.0                     300.0
# 430878                             80.0                     300.0
# 249899                             80.0                     500.0
# 568128                             80.0                     400.0
# 49467                              60.0                     200.0
# 600632                             60.0                     150.0
# 564827                             80.0                     400.0
# 499652                             60.0                     200.0
# 1540                               80.0                     400.0
# 104645                             60.0                     200.0
# 43767                              80.0                     300.0
# 264813                             80.0                     400.0
# 53820                              60.0                     200.0
# 483395             Done                                                NaN
# 447476          Not yet                                                NaN
# 117238          Not yet                                                NaN
# 310793          Not yet                                                NaN
# 91558           Not yet                                                NaN
# 98576           Not yet  Dealings in which auction or arbiter participates
# 268334          Not yet                                                NaN
# 582816          Not yet                                                NaN
# 174063             Done                                                NaN
# 430878          Not yet                                                NaN
# 249899              NaN                                                NaN
# 568128             Done                                                NaN
# 49467              Done                                                NaN
# 600632             Done                                                NaN
# 564827          Not yet                                                NaN
# 499652          Not yet                                                NaN
# 1540            Not yet                                                NaN
# 104645          Not yet                                                NaN
# 43767           Not yet                                                NaN
# 264813          Not yet                                                NaN
# 53820           Not yet                                                NaN
# 223588          Not yet                                                NaN
# 204263             Done                                                NaN
# 260871          Not yet                                                NaN
# 27479           Not yet                                                NaN
# 478902          Not yet                                                NaN
# 31400              Done                                                NaN
# 27955           Not yet                                                NaN
# 509221          Not yet                                                NaN
# 382742          Not yet                                                NaN
# 76304           Not yet                                                NaN
# 105832             Done                                                NaN
# 222762          Not yet                                                NaN
# 109041             Done                                                NaN
# 613470             Done                                                NaN
# 323802          Not yet                                                NaN
# 114665          Not yet                                                NaN
# 490192              NaN                                                NaN
# 171459             Done                                                NaN
# 95676              Done                                                NaN
# 322106          Not yet                                                NaN
# 491207             Done                                                NaN

# %% [markdown]
# Let us check the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (617859, 38)

# %% [markdown]
# Let us also look at the data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617859 entries, 0 to 617858
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   No                               617859 non-null  int64
#  1   RealEstateType                   617859 non-null  object
#  2   SurroundingArea                  0 non-null       float64
#  3   CityCode                         617859 non-null  int64
#  4   PrefectureName                   617859 non-null  object
#  5   CityName                         617859 non-null  object
#  6   DistrictName                     617569 non-null  object
#  7   NearestStation                   615272 non-null  object
#  8   TimeToNearestStationOriginal     594846 non-null  object
#  9   MinTimeToNearestStation          594846 non-null  float64
#  10  MaxTimeToNearestStation          594037 non-null  float64
#  11  TradePriceYen                    617859 non-null  int64
#  12  FloorPlan                        597170 non-null  object
#  13  SurveyedAreaM2                   617859 non-null  int64
#  14  AreaIsGreaterFlag                617859 non-null  int64
#  15  UnitLandPricePerM2Yen            0 non-null       float64
#  16  UnitLandPricePerTsuboYen         0 non-null       float64
#  17  LandShape                        0 non-null       float64
#  18  FrontageM                        0 non-null       float64
#  19  FrontageIsGreaterFlag            617859 non-null  bool
#  20  TotalFloorAreaM2                 0 non-null       float64
#  21  TotalFloorAreaIsGreaterFlag      617859 non-null  int64
#  22  ConstructionYear                 600333 non-null  float64
#  23  PrewarBuildingFlag               617859 non-null  int64
#  24  BuildingStructure                605241 non-null  object
#  25  CurrentUsage                     577978 non-null  object
#  26  FutureUsePurpose                 256686 non-null  object
#  27  FrontageRoadDirection            0 non-null       float64
#  28  FrontageRoadClassification       0 non-null       float64
#  29  FrontageRoadBreadthM             0 non-null       float64
#  30  CityPlanningCategory             599636 non-null  object
#  31  MaxBuildingCoverageRatioPercent  595793 non-null  float64
#  32  MaxFloorAreaRatioPercent         595793 non-null  float64
#  33  TransactionPeriod                617859 non-null  object
#  34  TransactionYear                  617859 non-null  int64
#  35  TransactionYearQuarter           617859 non-null  int64
#  36  RenovationStatus                 563396 non-null  object
#  37  Notes                            18072 non-null   object
# dtypes: bool(1), float64(14), int64(9), object(14)
# memory usage: 175.0+ MB

# %% [markdown]
# Let us check the null values

# %%
df.isna().sum()
# Out:
# No                                      0
# RealEstateType                          0
# SurroundingArea                    617859
# CityCode                                0
# PrefectureName                          0
# CityName                                0
# DistrictName                          290
# NearestStation                       2587
# TimeToNearestStationOriginal        23013
# MinTimeToNearestStation             23013
# MaxTimeToNearestStation             23822
# TradePriceYen                           0
# FloorPlan                           20689
# SurveyedAreaM2                          0
# AreaIsGreaterFlag                       0
# UnitLandPricePerM2Yen              617859
# UnitLandPricePerTsuboYen           617859
# LandShape                          617859
# FrontageM                          617859
# FrontageIsGreaterFlag                   0
# TotalFloorAreaM2                   617859
# TotalFloorAreaIsGreaterFlag             0
# ConstructionYear                    17526
# PrewarBuildingFlag                      0
# BuildingStructure                   12618
# CurrentUsage                        39881
# FutureUsePurpose                   361173
# FrontageRoadDirection              617859
# FrontageRoadClassification         617859
# FrontageRoadBreadthM               617859
# CityPlanningCategory                18223
# MaxBuildingCoverageRatioPercent     22066
# MaxFloorAreaRatioPercent            22066
# TransactionPeriod                       0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                    54463
# Notes                              599787
# dtype: int64

# %% [markdown]
# Percentage of null values from total dataset

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# No                                   0.000000
# RealEstateType                       0.000000
# SurroundingArea                    100.000000
# CityCode                             0.000000
# PrefectureName                       0.000000
# CityName                             0.000000
# DistrictName                         0.046936
# NearestStation                       0.418704
# TimeToNearestStationOriginal         3.724636
# MinTimeToNearestStation              3.724636
# MaxTimeToNearestStation              3.855572
# TradePriceYen                        0.000000
# FloorPlan                            3.348499
# SurveyedAreaM2                       0.000000
# AreaIsGreaterFlag                    0.000000
# UnitLandPricePerM2Yen              100.000000
# UnitLandPricePerTsuboYen           100.000000
# LandShape                          100.000000
# FrontageM                          100.000000
# FrontageIsGreaterFlag                0.000000
# TotalFloorAreaM2                   100.000000
# TotalFloorAreaIsGreaterFlag          0.000000
# ConstructionYear                     2.836570
# PrewarBuildingFlag                   0.000000
# BuildingStructure                    2.042214
# CurrentUsage                         6.454709
# FutureUsePurpose                    58.455570
# FrontageRoadDirection              100.000000
# FrontageRoadClassification         100.000000
# FrontageRoadBreadthM               100.000000
# CityPlanningCategory                 2.949378
# MaxBuildingCoverageRatioPercent      3.571365
# MaxFloorAreaRatioPercent             3.571365
# TransactionPeriod                    0.000000
# TransactionYear                      0.000000
# TransactionYearQuarter               0.000000
# RenovationStatus                     8.814794
# Notes                               97.075061
# dtype: float64

# %% [markdown]
# Here few columns have no values at all. Also dropping the `RealEstateType` column as there is only one type

# %%
df.drop(columns=['SurroundingArea','UnitLandPricePerM2Yen',
       'UnitLandPricePerTsuboYen', 'LandShape', 'FrontageM',
       'FrontageIsGreaterFlag', 'TotalFloorAreaM2',
       'TotalFloorAreaIsGreaterFlag','FrontageRoadDirection', 'FrontageRoadClassification',
       'FrontageRoadBreadthM','RealEstateType'], inplace=True)
df.head()
# Out:
#    No  CityCode PrefectureName                CityName DistrictName  \
# 0   3      1101       Hokkaido  Chuo Ward,Sapporo City   Asahigaoka
# 1  10      1101       Hokkaido  Chuo Ward,Sapporo City   Asahigaoka
# 2  14      1101       Hokkaido  Chuo Ward,Sapporo City   Asahigaoka
# 3  20      1101       Hokkaido  Chuo Ward,Sapporo City   Asahigaoka
# 4  25      1101       Hokkaido  Chuo Ward,Sapporo City   Asahigaoka
#
#   NearestStation TimeToNearestStationOriginal  MinTimeToNearestStation  \
# 0   Maruyamakoen                           20                     20.0
# 1   Maruyamakoen                           23                     23.0
# 2   Maruyamakoen                           25                     25.0
# 3   Maruyamakoen                          NaN                      NaN
# 4   Maruyamakoen                            0                      0.0
#
#    MaxTimeToNearestStation  TradePriceYen FloorPlan  SurveyedAreaM2  \
# 0                     20.0       19000000      4LDK              95
# 1                     23.0       14000000      4LDK              90
# 2                     25.0       27000000      2LDK              80
# 3                      NaN       30000000      4LDK             120
# 4                      0.0       19000000      4LDK              95
#
#    AreaIsGreaterFlag  ConstructionYear  PrewarBuildingFlag BuildingStructure  \
# 0                  0            1997.0                   0                RC
# 1                  0            1989.0                   0                RC
# 2                  0            2002.0                   0                RC
# 3                  0            2002.0                   0               NaN
# 4                  0            1997.0                   0                RC
#
#   CurrentUsage FutureUsePurpose  \
# 0          NaN            House
# 1        House            House
# 2        House              NaN
# 3        House              NaN
# 4        House              NaN
#
#                                 CityPlanningCategory  \
# 0                       Neighborhood Commercial Zone
# 1  Category I Exclusively Low-story Residential Zone
# 2                        Category I Residential Zone
# 3                        Category I Residential Zone
# 4                                                NaN
#
#    MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 0                             80.0                     200.0
# 1                             40.0                      80.0
# 2                             60.0                     200.0
# 3                             60.0                     200.0
# 4                              NaN                       NaN
#
#   TransactionPeriod  TransactionYear  TransactionYearQuarter RenovationStatus  \
# 0  4th quarter 2018             2018                       4          Not yet
# 1  4th quarter 2017             2017                       4          Not yet
# 2  2nd quarter 2010             2010                       2          Not yet
# 3  3rd quarter 2006             2006                       3          Not yet
# 4  1st quarter 2011             2011                       1          Not yet
#
#   Notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df.shape
# Out:
# (617859, 26)

# %%
df.isna().sum()
# Out:
# No                                      0
# CityCode                                0
# PrefectureName                          0
# CityName                                0
# DistrictName                          290
# NearestStation                       2587
# TimeToNearestStationOriginal        23013
# MinTimeToNearestStation             23013
# MaxTimeToNearestStation             23822
# TradePriceYen                           0
# FloorPlan                           20689
# SurveyedAreaM2                          0
# AreaIsGreaterFlag                       0
# ConstructionYear                    17526
# PrewarBuildingFlag                      0
# BuildingStructure                   12618
# CurrentUsage                        39881
# FutureUsePurpose                   361173
# CityPlanningCategory                18223
# MaxBuildingCoverageRatioPercent     22066
# MaxFloorAreaRatioPercent            22066
# TransactionPeriod                       0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                    54463
# Notes                              599787
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# No                                  0.000000
# CityCode                            0.000000
# PrefectureName                      0.000000
# CityName                            0.000000
# DistrictName                        0.046936
# NearestStation                      0.418704
# TimeToNearestStationOriginal        3.724636
# MinTimeToNearestStation             3.724636
# MaxTimeToNearestStation             3.855572
# TradePriceYen                       0.000000
# FloorPlan                           3.348499
# SurveyedAreaM2                      0.000000
# AreaIsGreaterFlag                   0.000000
# ConstructionYear                    2.836570
# PrewarBuildingFlag                  0.000000
# BuildingStructure                   2.042214
# CurrentUsage                        6.454709
# FutureUsePurpose                   58.455570
# CityPlanningCategory                2.949378
# MaxBuildingCoverageRatioPercent     3.571365
# MaxFloorAreaRatioPercent            3.571365
# TransactionPeriod                   0.000000
# TransactionYear                     0.000000
# TransactionYearQuarter              0.000000
# RenovationStatus                    8.814794
# Notes                              97.075061
# dtype: float64

# %% [markdown]
# # DEALING WITH OUTLIERS

# %%
df['TradePriceYen'].describe()
# Out:
# count    6.178590e+05
# mean     2.199517e+07
# std      2.511191e+07
# min      4.500000e+02
# 25%      1.000000e+07
# 50%      1.800000e+07
# 75%      2.800000e+07
# max      8.600000e+09
# Name: TradePriceYen, dtype: float64

# %% [markdown]
# The max value is extremely high and this might cause discrepencies. There are outliers in the data.Taking only the extreme values as the outliers

# %%
# Calculate the median
median = df['TradePriceYen'].median()

# Quartiles (Q1 and Q3)
q1 = df['TradePriceYen'].quantile(0.25)
q3 = df['TradePriceYen'].quantile(0.995)

# Interquartile range (IQR)
iqr = q3 - q1

# Determining the outliers
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['TradePriceYen'], vert=False)
plt.title('TradePriceYen Box Plot')
plt.xlabel('TradePriceYen')

# Marking the outliers
# Identifying outliers based on TradePriceYen using lower and upper bounds
outliers = df[(df['TradePriceYen'] < lower_bound) | (df['TradePriceYen'] > upper_bound)]['TradePriceYen']
# Plotting outliers on a horizontal line at y=1
plt.plot(outliers, [1] * len(outliers), 'ro', label='Outliers')

plt.legend()
plt.xscale('log')

plt.show()

# %%
# Showing only rows where 'TradePriceYen' is less than the 99.5th percentile
df[df['TradePriceYen'] < df['TradePriceYen'].quantile(0.995)]
# Out:
#            No  CityCode      PrefectureName                CityName  \
# 0           3      1101            Hokkaido  Chuo Ward,Sapporo City
# 1          10      1101            Hokkaido  Chuo Ward,Sapporo City
# 2          14      1101            Hokkaido  Chuo Ward,Sapporo City
# 3          20      1101            Hokkaido  Chuo Ward,Sapporo City
# 4          25      1101            Hokkaido  Chuo Ward,Sapporo City
# ...       ...       ...                 ...                     ...
# 617854  29892     47211  Okinawa Prefecture            Okinawa City
# 617855  29921     47211  Okinawa Prefecture            Okinawa City
# 617856  29959     47211  Okinawa Prefecture            Okinawa City
# 617857  29997     47211  Okinawa Prefecture            Okinawa City
# 617858  30381     47213  Okinawa Prefecture              Uruma City
#
#         DistrictName NearestStation TimeToNearestStationOriginal  \
# 0         Asahigaoka   Maruyamakoen                           20
# 1         Asahigaoka   Maruyamakoen                           23
# 2         Asahigaoka   Maruyamakoen                           25
# 3         Asahigaoka   Maruyamakoen                          NaN
# 4         Asahigaoka   Maruyamakoen                            0
# ...              ...            ...                          ...
# 617854        Tobaru            NaN                          NaN
# 617855   Aza Hiyagon            NaN                          NaN
# 617856      Miyazato            NaN                          NaN
# 617857      Yamazato            NaN                          NaN
# 617858  Aza Kawasaki            NaN                          NaN
#
#         MinTimeToNearestStation  MaxTimeToNearestStation  TradePriceYen  \
# 0                          20.0                     20.0       19000000
# 1                          23.0                     23.0       14000000
# 2                          25.0                     25.0       27000000
# 3                           NaN                      NaN       30000000
# 4                           0.0                      0.0       19000000
# ...                         ...                      ...            ...
# 617854                      NaN                      NaN        5800000
# 617855                      NaN                      NaN        5000000
# 617856                      NaN                      NaN        6500000
# 617857                      NaN                      NaN        7000000
# 617858                      NaN                      NaN        4900000
#
#        FloorPlan  SurveyedAreaM2  AreaIsGreaterFlag  ConstructionYear  \
# 0           4LDK              95                  0            1997.0
# 1           4LDK              90                  0            1989.0
# 2           2LDK              80                  0            2002.0
# 3           4LDK             120                  0            2002.0
# 4           4LDK              95                  0            1997.0
# ...          ...             ...                ...               ...
# 617854      3LDK              80                  0            1985.0
# 617855      3LDK              60                  0            1984.0
# 617856      4LDK              85                  0            2001.0
# 617857       3DK              55                  0            1991.0
# 617858      2LDK              60                  0            1986.0
#
#         PrewarBuildingFlag BuildingStructure CurrentUsage FutureUsePurpose  \
# 0                        0                RC          NaN            House
# 1                        0                RC        House            House
# 2                        0                RC        House              NaN
# 3                        0               NaN        House              NaN
# 4                        0                RC        House              NaN
# ...                    ...               ...          ...              ...
# 617854                   0                RC        House              NaN
# 617855                   0                RC        House              NaN
# 617856                   0                RC        House              NaN
# 617857                   0                RC        House              NaN
# 617858                   0                RC        House              NaN
#
#                                      CityPlanningCategory  \
# 0                            Neighborhood Commercial Zone
# 1       Category I Exclusively Low-story Residential Zone
# 2                             Category I Residential Zone
# 3                             Category I Residential Zone
# 4                                                     NaN
# ...                                                   ...
# 617854                     Non-divided City Planning Area
# 617855                     Non-divided City Planning Area
# 617856                     Non-divided City Planning Area
# 617857                       Neighborhood Commercial Zone
# 617858                     Non-divided City Planning Area
#
#         MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 0                                  80.0                     200.0
# 1                                  40.0                      80.0
# 2                                  60.0                     200.0
# 3                                  60.0                     200.0
# 4                                   NaN                       NaN
# ...                                 ...                       ...
# 617854                              NaN                       NaN
# 617855                             70.0                     200.0
# 617856                             70.0                     200.0
# 617857                             80.0                     300.0
# 617858                             60.0                     200.0
#
#        TransactionPeriod  TransactionYear  TransactionYearQuarter  \
# 0       4th quarter 2018             2018                       4
# 1       4th quarter 2017             2017                       4
# 2       2nd quarter 2010             2010                       2
# 3       3rd quarter 2006             2006                       3
# 4       1st quarter 2011             2011                       1
# ...                  ...              ...                     ...
# 617854  2nd quarter 2008             2008                       2
# 617855  3rd quarter 2006             2006                       3
# 617856  4th quarter 2008             2008                       4
# 617857  1st quarter 2008             2008                       1
# 617858  4th quarter 2007             2007                       4
#
#        RenovationStatus                                              Notes
# 0               Not yet                                                NaN
# 1               Not yet                                                NaN
# 2               Not yet                                                NaN
# 3               Not yet                                                NaN
# 4               Not yet                                                NaN
# ...                 ...                                                ...
# 617854          Not yet                                                NaN
# 617855          Not yet                                                NaN
# 617856          Not yet  Dealings in which auction or arbiter participates
# 617857          Not yet  Dealings in which auction or arbiter participates
# 617858          Not yet  Dealings in which auction or arbiter participates
#
# [614694 rows x 26 columns]

# %%
df.shape
# Out:
# (617859, 26)

# %% [markdown]
# 3000 Odd data are outliers and they are not that significant looking at our total number of rows.
#
# Dropping the potential outliers

# %%
# Taking quantile as 0.995
quantile_value = df['TradePriceYen'].quantile(0.995)
#Assigning excluding the 3000 rows to df
df = df[df['TradePriceYen'] < quantile_value]
df['TradePriceYen'].describe()
# Out:
# count    6.146940e+05
# mean     2.114970e+07
# std      1.491496e+07
# min      4.500000e+02
# 25%      1.000000e+07
# 50%      1.800000e+07
# 75%      2.800000e+07
# max      1.000000e+08
# Name: TradePriceYen, dtype: float64

# %% [markdown]
# This means that the model has a limitation in TradePriceYen and looks at only prices till 100,000,000.

# %% [markdown]
# AreaIsGreaterFlag:	An area of 2000 m^2 or greater, the area data are displayed 2000, and this flag is true.
# PrewarBuilding: Buildings built before 1945, the construction year data are displayed as “before the war.” The BuildYear is converted to 1945, and added this flag.

# %%
df["AreaIsGreaterFlag"].value_counts()
# Out:
# AreaIsGreaterFlag
# 0    614692
# 1         2
# Name: count, dtype: int64

# %% [markdown]
# There are just two data points.

# %%
df["PrewarBuildingFlag"].value_counts()
# Out:
# PrewarBuildingFlag
# 0    614144
# 1       550
# Name: count, dtype: int64

# %% [markdown]
# There are 533 units. But I am not considering the building before 1945.
#
#
# Hence dropping these rows where the flag is 1 and dropping the columns.

# %%
# Dropping rows based on condition where they are 1
df = df[(df["AreaIsGreaterFlag"] == False) & (df["PrewarBuildingFlag"] == False)]
# Dropping columns
df = df.drop(columns=["AreaIsGreaterFlag", "PrewarBuildingFlag"])

# %%
df.shape
# Out:
# (614142, 24)

# %% [markdown]
# Japan's main level of administaration is prefectures. The administrative structure can differ from one place to another in Japan, and not all cities have associated district names and vice versa. The specific naming conventions and divisions are determined by local government authorities and can vary based on historical, geographical, and administrative factors.

# %%
# List of columns related to the area
Area_cols = ['DistrictName', 'CityCode', 'CityName', 'PrefectureName']
# Iterate through each area related column
for column in Area_cols:
    # Displaying the the column name
    print(column)
    # Printing the number of unique values in the column
    print(df[column].nunique())
# Out:
# DistrictName
# 12022
# CityCode
# 618
# CityName
# 617
# PrefectureName
# 47

# %% [markdown]
# Hence just using prefectures is less ambiguous and for now not looking into more granularity. For now just dropping DistrictNames,CityCode and CityName columns.

# %%
#Dropping area related columns
df.drop(columns=['DistrictName','CityCode','CityName'], inplace=True)
df.isna().sum()
# Out:
# No                                      0
# PrefectureName                          0
# NearestStation                       2577
# TimeToNearestStationOriginal        22857
# MinTimeToNearestStation             22857
# MaxTimeToNearestStation             23663
# TradePriceYen                           0
# FloorPlan                           20513
# SurveyedAreaM2                          0
# ConstructionYear                    17461
# BuildingStructure                   12561
# CurrentUsage                        39569
# FutureUsePurpose                   359161
# CityPlanningCategory                18132
# MaxBuildingCoverageRatioPercent     21954
# MaxFloorAreaRatioPercent            21954
# TransactionPeriod                       0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                    54098
# Notes                              596103
# dtype: int64

# %% [markdown]
# Also dropping the the column `No`

# %%
df.drop(columns=['No'], inplace=True)

# %% [markdown]
# # Dealing with Duplicates

# %%
df.duplicated().sum()
# Out:
# 7369

# %% [markdown]
# The dupication might be because in Apartment or Condo buildings there might be simillar condos going at the same price with the same attributes. So for further analysis dropping these as it will just be redundant information.

# %%
# Drop duplicate columns
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (606773, 20)

# %%
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                       2557
# TimeToNearestStationOriginal        22305
# MinTimeToNearestStation             22305
# MaxTimeToNearestStation             23107
# TradePriceYen                           0
# FloorPlan                           20335
# SurveyedAreaM2                          0
# ConstructionYear                    17377
# BuildingStructure                   12475
# CurrentUsage                        39460
# FutureUsePurpose                   353443
# CityPlanningCategory                17939
# MaxBuildingCoverageRatioPercent     21728
# MaxFloorAreaRatioPercent            21728
# TransactionPeriod                       0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                    53178
# Notes                              588847
# dtype: int64

# %% [markdown]
# So I just require a single time value called Time to nearest station instead of Max and min values for time to nearest station for analysis. I will just take the max time to reach the nearest station as a standard value. and fill the empty `MaxTimeToNearestStation` with the `MinTimeToNearestStation` because in the original data it just has a single time andd has no min-max times.

# %%
# Fill missing values in 'MaxTimeToNearestStation' with corresponding values from 'MinTimeToNearestStation'
df['MaxTimeToNearestStation'].fillna(df['MinTimeToNearestStation'], inplace=True)
# Droping unnecessary columns 'TimeToNearestStationOriginal' and 'MinTimeToNearestStation'
df.drop(columns=["TimeToNearestStationOriginal", "MinTimeToNearestStation"], inplace=True)
# Displaying the count of missing values
missing_values_count = df.isna().sum()
print(missing_values_count)
# Out:
# PrefectureName                          0
# NearestStation                       2557
# MaxTimeToNearestStation             22305
# TradePriceYen                           0
# FloorPlan                           20335
# SurveyedAreaM2                          0
# ConstructionYear                    17377
# BuildingStructure                   12475
# CurrentUsage                        39460
# FutureUsePurpose                   353443
# CityPlanningCategory                17939
# MaxBuildingCoverageRatioPercent     21728
# MaxFloorAreaRatioPercent            21728
# TransactionPeriod                       0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                    53178
# Notes                              588847
# dtype: int64

# %% [markdown]
# Drop `TransactionPeriod` because it is redundant in `TransactionYearQuarter` and `TransactionYear`

# %%
#Dropping column `TransactionPeriod`
df.drop(columns=['TransactionPeriod'], inplace=True)

# %%
df.head()
# Out:
#   PrefectureName NearestStation  MaxTimeToNearestStation  TradePriceYen  \
# 0       Hokkaido   Maruyamakoen                     20.0       19000000
# 1       Hokkaido   Maruyamakoen                     23.0       14000000
# 2       Hokkaido   Maruyamakoen                     25.0       27000000
# 3       Hokkaido   Maruyamakoen                      NaN       30000000
# 4       Hokkaido   Maruyamakoen                      0.0       19000000
#
#   FloorPlan  SurveyedAreaM2  ConstructionYear BuildingStructure CurrentUsage  \
# 0      4LDK              95            1997.0                RC          NaN
# 1      4LDK              90            1989.0                RC        House
# 2      2LDK              80            2002.0                RC        House
# 3      4LDK             120            2002.0               NaN        House
# 4      4LDK              95            1997.0                RC        House
#
#   FutureUsePurpose                               CityPlanningCategory  \
# 0            House                       Neighborhood Commercial Zone
# 1            House  Category I Exclusively Low-story Residential Zone
# 2              NaN                        Category I Residential Zone
# 3              NaN                        Category I Residential Zone
# 4              NaN                                                NaN
#
#    MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  TransactionYear  \
# 0                             80.0                     200.0             2018
# 1                             40.0                      80.0             2017
# 2                             60.0                     200.0             2010
# 3                             60.0                     200.0             2006
# 4                              NaN                       NaN             2011
#
#    TransactionYearQuarter RenovationStatus Notes
# 0                       4          Not yet   NaN
# 1                       4          Not yet   NaN
# 2                       2          Not yet   NaN
# 3                       3          Not yet   NaN
# 4                       1          Not yet   NaN

# %%
df['Notes'].value_counts()
# Out:
# Notes
# Dealings in which auction or arbiter participates                                                           16881
# Dealings between related objects                                                                              843
# Dealings including special circumstances                                                                       85
# Dealings of real estate that includes wound etc.                                                               64
# Dealings of real estate to which mortgage etc. are set                                                         46
# Dealings in which auction or arbiter participates,Dealings of real estate that includes wound etc.              2
# Dealings of real estate to which mortgage etc. are set,Dealings in which auction or arbiter participates        2
# Dealings between related objects,Dealings in which auction or arbiter participates                              2
# Dealings between related objects,Dealings of real estate that includes wound etc.                               1
# Name: count, dtype: int64

# %% [markdown]
# Here 97% rows for Notes(About dealings) are empty so dropping the column.

# %%
# Dropping the column notes
df.drop(columns=['Notes'], inplace=True)

# %% [markdown]
# # Dealing with nulls

# %% [markdown]
# Let us look at Rennovation status firstly.

# %%
# Rows where 'RenovationStatus' is null
renovation_null_rows = df[df['RenovationStatus'].isna()]
# value counts of 'CurrentUsage' for the filtered rows
current_usage_counts = renovation_null_rows['CurrentUsage'].value_counts()
#Value counts of CurrentUsage for RenovationStatus is null
print(current_usage_counts)
# Out:
# CurrentUsage
# House                46410
# Shop                   365
# Office                 333
# Other                  129
# Parking Lot             36
# Warehouse               10
# Office, Shop             9
# House, Shop              6
# House, Office            2
# House, Other             2
# Warehouse, Shop          1
# Parking Lot, Shop        1
# Factory                  1
# Name: count, dtype: int64

# %% [markdown]
# The above EDA was to check if there was a relation between Renovation Status and current usage. It was to check if there was a certain category of building that had Renovation status as null. But doesn't seem to have a pattern. It can be checked with other columns as well. As of now no relation was found.

# %%
df['RenovationStatus'].value_counts()
# Out:
# RenovationStatus
# Not yet    398751
# Done       154844
# Name: count, dtype: int64

# %%
# Counting the number of records for each unique 'RenovationStatus' value
renovation_counts = df['RenovationStatus'].value_counts()
#Bar plot
plt.figure(figsize=(5, 5))
renovation_counts.plot(kind='bar')
plt.title('Count of Records by Renovation Status')
plt.xlabel('Renovation Status')
plt.ylabel('Count of Records')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Let us look if there was a year range where `RenovationStatus` was Not yet or Done so that we can impute  the values.

# %%
# Filter rows where 'RenovationStatus' is 'Not yet' or 'Done'
renov_df = df[df['RenovationStatus'].isin(['Not yet', 'Done'])]
# Grouping the filtered data by 'RenovationStatus' and calculate the range of 'ConstructionYear'
range_of_construction_years = renov_df.groupby('RenovationStatus')['ConstructionYear'].agg(['min', 'max'])
print(range_of_construction_years)
# Out:
#                      min     max
# RenovationStatus
# Done              1946.0  2019.0
# Not yet           1946.0  2019.0

# %% [markdown]
# No such year range. Let us then impute according to the ratio of the value counts.

# %%
# Total number of null values to impute
total_null_values = df['RenovationStatus'].isnull().sum()
# The desired ratio from my value_counts
desired_ratio = 398751/154844
# The number of imputed values for "Not yet" and "Done" based on the ratio
num_not_yet = round(total_null_values / (desired_ratio + 1))
num_done = total_null_values - num_not_yet
# Creating a list of imputed values where the count is based on the calculated numbers for "Not yet" and "Done".
imputed_values = ['Not yet'] * num_not_yet + ['Done'] * num_done
# Shuffling the list to assign values randomly
random.shuffle(imputed_values)
# Replacing the null values with the imputed values
df.loc[df['RenovationStatus'].isnull(), 'RenovationStatus'] = imputed_values

# %%
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                       2557
# MaxTimeToNearestStation             22305
# TradePriceYen                           0
# FloorPlan                           20335
# SurveyedAreaM2                          0
# ConstructionYear                    17377
# BuildingStructure                   12475
# CurrentUsage                        39460
# FutureUsePurpose                   353443
# CityPlanningCategory                17939
# MaxBuildingCoverageRatioPercent     21728
# MaxFloorAreaRatioPercent            21728
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# dtype: int64

# %% [markdown]
# To impute the values in `MaxTimeToNearestStation` first group by the `NearestStation` and find the corresponding mean time for those stations and then impute that mean to matching `MaxTimeToNearestStation`.

# %%
# Group by 'NearestStation' and calculate the mean of 'MaxTimeToNearestStation'
mean_max_time_by_station = df.groupby('NearestStation')['MaxTimeToNearestStation'].mean()
print(mean_max_time_by_station)
# Out:
# NearestStation
# Abekawa                    20.571429
# Abeno                       3.958621
# Abeyamakoen                 9.339623
# Abiko                       9.239394
# Abikocho                    5.518519
#                              ...
# Zeze                       10.605714
# Zoshigaya (Tokyo Metro)     4.441065
# Zoshiki                     8.593148
# Zuiko 4-chome               7.137931
# Zushi                      55.525469
# Name: MaxTimeToNearestStation, Length: 3778, dtype: float64

# %%
# Filling missing values in 'MaxTimeToNearestStation' based on the mean values
df['MaxTimeToNearestStation'].fillna(df['NearestStation'].map(mean_max_time_by_station), inplace=True)
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                       2557
# MaxTimeToNearestStation              2585
# TradePriceYen                           0
# FloorPlan                           20335
# SurveyedAreaM2                          0
# ConstructionYear                    17377
# BuildingStructure                   12475
# CurrentUsage                        39460
# FutureUsePurpose                   353443
# CityPlanningCategory                17939
# MaxBuildingCoverageRatioPercent     21728
# MaxFloorAreaRatioPercent            21728
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# dtype: int64

# %% [markdown]
# Now we cannot impute values in `NearestStation` randomly and hence cannot impute `MaxTimeToNearestStation`. Dropping the rest of the null values in `MaxTimeToNearestStation`.

# %%
#Dropping the null rows in `MaxTimeToNearestStation`
df.dropna(subset = ["MaxTimeToNearestStation"], inplace=True)

# %% [markdown]
# These are the grouping of each Station and their times. Fillng missing values in 'MaxTimeToNearestStation' based on the mean values from this mapping.

# %%
#Renaming MaxTimeToNearestStation to TimeToNearestStation
df.rename(columns={'MaxTimeToNearestStation': 'TimeToNearestStation'}, inplace=True)

# %%
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                           19981
# SurveyedAreaM2                          0
# ConstructionYear                    16707
# BuildingStructure                   12300
# CurrentUsage                        39397
# FutureUsePurpose                   351146
# CityPlanningCategory                16327
# MaxBuildingCoverageRatioPercent     20074
# MaxFloorAreaRatioPercent            20074
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# dtype: int64

# %% [markdown]
# Identify the unique categories of `FloorPlan` that are most common for different ranges or bins of `SurveyedAreaM2`.
# For each unique `FloorPlan` category, calculate the most frequent 'SurveyedAreaM2' range or bin.
# Fill missing values in `FloorPlan` based on the most common 'FloorPlan' category for the corresponding `SurveyedAreaM2` range.

# %%
# Bin edges for 'SurveyedAreaM2'
bin_edges = [0, 250, 500, 1000, 1250, 1500,1750,2000] 

# New column 'SurveyedAreaM2_Bin' to represent bins
df['SurveyedAreaM2_Bin'] = pd.cut(df['SurveyedAreaM2'], bin_edges)
#print(df['SurveyedAreaM2_Bin'])

def get_mode_or_default(group, default_value):
    try:
        #Filtering out 'Unknown' values within the group
        valid_values = group[group != 'Unknown']
        # Mode for the remaining valid values
        mode_value = valid_values.mode().iloc[0]
        #Returning the calculated mode
        return mode_value
    except IndexError:
        #If there is no mode (e.g., all values are 'Unknown'), return the default value
        return default_value

# Most frequent 'FloorPlan' category for each 'SurveyedAreaM2' bin
# The function takes each group 'x' and calculates the most frequent 'FloorPlan' category for that group using the get_mode_or_default function. 
most_frequent_floorplan=df.groupby('SurveyedAreaM2_Bin')['FloorPlan'].apply(lambda x: get_mode_or_default(x, default_value='Unknown'))
print(most_frequent_floorplan)

# Filling missing values in 'FloorPlan' based on the most frequent category for each 'SurveyedAreaM2' bin
df['FloorPlan'] = df['FloorPlan'].fillna(df['SurveyedAreaM2_Bin'].map(most_frequent_floorplan))
# Out:
# SurveyedAreaM2_Bin
# (0, 250]              3LDK
# (250, 500]      Open Floor
# (500, 1000]     Open Floor
# (1000, 1250]       Unknown
# (1250, 1500]    Open Floor
# (1500, 1750]       Unknown
# (1750, 2000]       Unknown
# Name: FloorPlan, dtype: object

# %%
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                    16707
# BuildingStructure                   12300
# CurrentUsage                        39397
# FutureUsePurpose                   351146
# CityPlanningCategory                16327
# MaxBuildingCoverageRatioPercent     20074
# MaxFloorAreaRatioPercent            20074
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# Here I am finding the median of `MaxBuildingCoverageRatioPercent`and `MaxFloorAreaRatioPercent` for each `Floor plan` and `SurroundingAreaM2`group.Taking median because it is less sensitive to outliers compared to the mean provides a more robust measure of central tendency.
#
# Then filling the missing value in `MaxBuildingCoverageRatioPercent`and `MaxFloorAreaRatioPercent` with the median looking at the `Floor plan` and `SurroundingAreaM2`group. Now certain combinations can have nulls. Like in this:
#
# 4LDK              (0, 250]              60.0
#
#                   (250, 500]            60.0
#
#                   (500, 1000]           70.0
#
#                   (1000, 1250]           NaN (null combination)
#
#                   (1250, 1500]           NaN (null combination)
#
#                   (1500, 1750]           NaN (null combination)
#
#                   (1750, 2000]           NaN (null combination)
#
#
# It will remain null for such cases.In such cases I will drop the rows because then that is an outlier.

# %%
# Bin edges for 'SurveyedAreaM2'
bin_edges = [0, 250, 500, 1000, 1250, 1500, 1750, 2000]

# New column 'SurveyedAreaM2_Bin' to represent bins
df['SurveyedAreaM2_Bin'] = pd.cut(df['SurveyedAreaM2'], bins=bin_edges)

# Grouping the data by 'FloorPlan' and 'SurveyedAreaM2_Bin'
grouped_data = df.groupby(['FloorPlan', 'SurveyedAreaM2_Bin'])

# Calculating the median 'MaxBuildingCoverageRatioPercent' and 'MaxFloorAreaRatioPercent' for each group
median_max_building_coverage = grouped_data['MaxBuildingCoverageRatioPercent'].median()
median_max_floor_area = grouped_data['MaxFloorAreaRatioPercent'].median()
#print(median_max_building_coverage)
#print(median_max_floor_area)

# Filling null values in 'MaxBuildingCoverageRatioPercent' and 'MaxFloorAreaRatioPercent' based on the group medians
df['MaxBuildingCoverageRatioPercent'].fillna(df.set_index(['FloorPlan', 'SurveyedAreaM2_Bin'])['MaxBuildingCoverageRatioPercent'].fillna(median_max_building_coverage).reset_index()['MaxBuildingCoverageRatioPercent'], inplace=True)
df['MaxFloorAreaRatioPercent'].fillna(df.set_index(['FloorPlan', 'SurveyedAreaM2_Bin'])['MaxFloorAreaRatioPercent'].fillna(median_max_floor_area).reset_index()['MaxFloorAreaRatioPercent'], inplace=True)
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                    16707
# BuildingStructure                   12300
# CurrentUsage                        39397
# FutureUsePurpose                   351146
# CityPlanningCategory                16327
# MaxBuildingCoverageRatioPercent      1708
# MaxFloorAreaRatioPercent             1708
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %%
df.dropna(subset = ["MaxBuildingCoverageRatioPercent","MaxFloorAreaRatioPercent"], inplace=True)
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                    16309
# BuildingStructure                   12026
# CurrentUsage                        39192
# FutureUsePurpose                   350280
# CityPlanningCategory                14796
# MaxBuildingCoverageRatioPercent         0
# MaxFloorAreaRatioPercent                0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# Checking if I can fill the `ConstructionYear` with `BuildingStructure`.(Using Chi squared as it is categorical columns)

# %%
# from scipy.stats import f_oneway

# # Perform one-way ANOVA
# groups = [df[df['BuildingStructure'] == group]['ConstructionYear'] for group in df['BuildingStructure'].unique()]
# f_statistic, p_value = f_oneway(*groups)

# 2002.0                      0       0  0
# 2003.0                      0       2  1
# 2004.0                      0       0  3
# 2005.0                      0       1  4
# 2006.0                      0       5  4
# 2007.0                      0       0  3
# 2008.0                      0       0  0
# 2009.0                      0      10  1
# 2010.0                      0       0  0
# 2011.0                      0       0  0
# 2012.0                      0       0  0
# 2013.0                      0       0  1
# 2014.0                      0       0  0
# 2015.0                      0       0  9
# 2016.0                      0       0  0
# 2017.0                      0       0  1
# 2018.0                      0       0  0
# 2019.0                      0       0  0

# %%
df["BuildingStructure"].value_counts()
# Out:
# BuildingStructure
# RC            406762
# SRC           178553
# S               4006
# SRC, RC          618
# RC, S            256
# SRC, S           137
# W                 79
# B                 21
# LS                18
# SRC, RC, S         2
# RC, B              1
# RC, W              1
# Name: count, dtype: int64

# %%
# Grouping the data by 'ConstructionYear' and getting the unique 'BuildingStructure' values
construction_year_building_structure = df.groupby('ConstructionYear')['BuildingStructure'].unique()
# Calculating the most popular 'BuildingStructure' for each year
most_popular_structure = df.groupby('ConstructionYear')['BuildingStructure'].agg(lambda x: x.value_counts().idxmax())
result = pd.DataFrame({'ConstructionYear': most_popular_structure.index, 'MostPopularBuildingStructure': most_popular_structure.values})
print(result)
# Out:
#     ConstructionYear MostPopularBuildingStructure
# 0             1946.0                           RC
# 1             1947.0                           RC
# 2             1948.0                           RC
# 3             1949.0                           RC
# 4             1950.0                           RC
# 5             1951.0                          SRC
# 6             1952.0                           RC
# 7             1953.0                          SRC
# 8             1954.0                           RC
# 9             1955.0                           RC
# 10            1956.0                           RC
# 11            1957.0                           RC
# 12            1958.0                          SRC
# 13            1959.0                          SRC
# 14            1960.0                          SRC
# 15            1961.0                           RC
# 16            1962.0                           RC
# 17            1963.0                           RC
# 18            1964.0                           RC
# 19            1965.0                           RC
# 20            1966.0                           RC
# 21            1967.0                           RC
# 22            1968.0                           RC
# 23            1969.0                           RC
# 24            1970.0                           RC
# 25            1971.0                           RC
# 26            1972.0                           RC
# 27            1973.0                           RC
# 28            1974.0                          SRC
# 29            1975.0                          SRC
# 30            1976.0                           RC
# 31            1977.0                          SRC
# 32            1978.0                          SRC
# 33            1979.0                          SRC
# 34            1980.0                          SRC
# 35            1981.0                          SRC
# 36            1982.0                          SRC
# 37            1983.0                          SRC
# 38            1984.0                           RC
# 39            1985.0                           RC
# 40            1986.0                           RC
# 41            1987.0                           RC
# 42            1988.0                           RC
# 43            1989.0                           RC
# 44            1990.0                           RC
# 45            1991.0                           RC
# 46            1992.0                           RC
# 47            1993.0                           RC
# 48            1994.0                           RC
# 49            1995.0                           RC
# 50            1996.0                           RC
# 51            1997.0                           RC
# 52            1998.0                           RC
# 53            1999.0                           RC
# 54            2000.0                           RC
# 55            2001.0                           RC
# 56            2002.0                           RC
# 57            2003.0                           RC
# 58            2004.0                           RC
# 59            2005.0                           RC
# 60            2006.0                           RC
# 61            2007.0                           RC
# 62            2008.0                           RC
# 63            2009.0                           RC
# 64            2010.0                           RC
# 65            2011.0                           RC
# 66            2012.0                           RC
# 67            2013.0                           RC
# 68            2014.0                           RC
# 69            2015.0                           RC
# 70            2016.0                           RC
# 71            2017.0                           RC
# 72            2018.0                           RC
# 73            2019.0                           RC

# %% [markdown]
# With the `BuildingStructure` given I cannot fill the `ConstructionYear` as it can be any one of these years but I may do **vice versa**.

# %% [markdown]
# Filling `BuildingStructure` with `ConstructionYear`

# %%
# replacing missing 'BuildingStructure' values with the mode for their corresponding 'ConstructionYear'
df['BuildingStructure'] = df['BuildingStructure'].fillna(df['ConstructionYear'].map(most_popular_structure))
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                    16309
# BuildingStructure                    2275
# CurrentUsage                        39192
# FutureUsePurpose                   350280
# CityPlanningCategory                14796
# MaxBuildingCoverageRatioPercent         0
# MaxFloorAreaRatioPercent                0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# Construction year cannot be imputed so dropping all th missing values in that

# %%
# Dropping null rows in `ConstructionYear`
df.dropna(subset=['ConstructionYear'], inplace=True)
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                        0
# BuildingStructure                       0
# CurrentUsage                        36669
# FutureUsePurpose                   342697
# CityPlanningCategory                12089
# MaxBuildingCoverageRatioPercent         0
# MaxFloorAreaRatioPercent                0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# Now let us deal with FutureUsePurpose and CurrentUsage

# %% [markdown]
# Checking the relation of FloorPlan and Current usage.

# %%
# Contingency table
contingency_table = pd.crosstab(df['CurrentUsage'].fillna('Missing'), df['FloorPlan'])
# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 331917.0425800548, p-value: 0.0

# %% [markdown]
# A chi-squared test with a chi-squared statistic of 331917.0425800548 and a p-value of 0.0 is indicating an  strong association between the two categorical variables being tested. The p-value of 0.0 means that the observed relationship is highly significant and unlikely to have occurred by chance.

# %%
# Dictionary to store the mode of 'CurrentUsage' for each 'FloorPlan' code
floorplan_mode_dict = df.groupby('FloorPlan')['CurrentUsage'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
# Missing 'CurrentUsage' values
missing_current_usage = df['CurrentUsage'].isnull()
# Filling the missing values in 'CurrentUsage' based on the 'FloorPlan' mode
df.loc[missing_current_usage, 'CurrentUsage'] = df.loc[missing_current_usage, 'FloorPlan'].map(floorplan_mode_dict)
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                        0
# BuildingStructure                       0
# CurrentUsage                            0
# FutureUsePurpose                   342697
# CityPlanningCategory                12089
# MaxBuildingCoverageRatioPercent         0
# MaxFloorAreaRatioPercent                0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# `FutureUsePurpose` has 58% missing data.  So let us run few statistical tests to take the decision to drop them or not.

# %%
# Selecting rows where 'FutureUsePurpose' is not null
notna_rows = df[df['FutureUsePurpose'].notna()]
# Extracting specific columns ('FutureUsePurpose' and 'TradePriceYen') from the selected rows
selected_columns = notna_rows[['FutureUsePurpose', 'TradePriceYen']]
# Displaying the resulting DataFrame showing 'FutureUsePurpose' and 'TradePriceYen' columns
selected_columns
# Out:
#        FutureUsePurpose  TradePriceYen
# 0                 House       19000000
# 1                 House       14000000
# 6                 House       11000000
# 9                Office       13000000
# 12                House       40000000
# ...                 ...            ...
# 616841            House       15000000
# 616853            House       21000000
# 616862            House       18000000
# 616863            House       19000000
# 616901            House       21000000
#
# [243474 rows x 2 columns]

# %%
subset_df = df[df['FutureUsePurpose'].notna()][['FutureUsePurpose', 'TradePriceYen']]
# Grouping the data by 'FutureUsePurpose' and get the corresponding 'TradePriceYen' values
groups = {}
for future_use, group_data in subset_df.groupby('FutureUsePurpose'):
    groups[future_use] = group_data['TradePriceYen']
#ANOVA
f_statistic, p_value = f_oneway(*groups.values())
print("F-statistic:", f_statistic)
print("p-value:", p_value)
# Checking results
if p_value < 0.05:
    print("Reject the null hypothesis: There are significant differences between groups.")
else:
    print("Fail to reject the null hypothesis: There are no significant differences between groups.")
# Out:
# F-statistic: 562.1476624428938
# p-value: 0.0
# Reject the null hypothesis: There are significant differences between groups.

# %% [markdown]
# It assesses whether the categories have different average trade prices (mean values) and, if the p-value is significant, indicates that at least one category is different from the others in terms of the "TradePriceYen" variable.

# %%
# Checking the normality for each group using the Shapiro-Wilk test
for group, data in groups.items():
    _, p_value = stats.shapiro(data)
    print(f"Shapiro-Wilk p-value for group '{group}': {p_value}")
# Checking homoscedasticity using Levene's test
_, p_value = stats.levene(*groups.values())
print("Levene's Test p-value:", p_value)
# Out:
# Shapiro-Wilk p-value for group 'House': 0.0
# Shapiro-Wilk p-value for group 'Office': 0.0
# Shapiro-Wilk p-value for group 'Other': 0.0
# Shapiro-Wilk p-value for group 'Shop': 2.5505394471458157e-31
# Levene's Test p-value: 7.727742319401544e-100
# C:\Users\Thekku\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# The statistical tests show that the data does not meet the assumptions of normality and homoscedasticity, which are required for traditional parametric tests like the ANOVA. Given these violations, it is more appropriate to use non-parametric tests, such as the Kruskal-Wallis test, to compare the groups. The Kruskal-Wallis test is robust to these assumptions and is suitable for your data when normality and equal variance assumptions are not met.

# %%
# Kruskal-Wallis test
_, p_value = kruskal(*groups.values())
print("Kruskal-Wallis Test p-value:", p_value)
# If the Kruskal-Wallis test is significant (p-value < 0.05), perform Dunn test
if p_value < 0.05:
    dunn_results = sp.posthoc_dunn(subset_df, val_col='TradePriceYen', group_col='FutureUsePurpose', p_adjust='bonferroni')
    print("Dunn Test Results:")
    print(dunn_results)
else:
    print("Kruskal-Wallis test is not significant. No post-hoc tests performed.")
# Out:
# Kruskal-Wallis Test p-value: 0.0
# Dunn Test Results:
#                 House         Office     Other          Shop
# House    1.000000e+00  8.691254e-122  0.000000  1.681190e-20
# Office  8.691254e-122   1.000000e+00  0.000382  1.820986e-03
# Other    0.000000e+00   3.815683e-04  1.000000  6.639046e-01
# Shop     1.681190e-20   1.820986e-03  0.663905  1.000000e+00

# %% [markdown]
# The Kruskal-Wallis test has produced a highly significant p-value (p-value: 0.0), indicating that there are significant differences among the groups. This result aligns with the findings from the Dunn test, which is a post-hoc test used for pairwise comparisons between the groups.
#
# Note:There is not significant difference between other and shops.

# %% [markdown]
# Let us not drop them and impute missing values

# %%
df.columns
# Out:
# Index(['PrefectureName', 'NearestStation', 'TimeToNearestStation',
#        'TradePriceYen', 'FloorPlan', 'SurveyedAreaM2', 'ConstructionYear',
#        'BuildingStructure', 'CurrentUsage', 'FutureUsePurpose',
#        'CityPlanningCategory', 'MaxBuildingCoverageRatioPercent',
#        'MaxFloorAreaRatioPercent', 'TransactionYear', 'TransactionYearQuarter',
#        'RenovationStatus', 'SurveyedAreaM2_Bin'],
#       dtype='object')

# %%
df['FutureUsePurpose'].value_counts(dropna=False)
# Out:
# FutureUsePurpose
# NaN       342697
# House     226209
# Other      13675
# Office      2694
# Shop         896
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# PrefectureName                          0
# NearestStation                          0
# TimeToNearestStation                    0
# TradePriceYen                           0
# FloorPlan                               0
# SurveyedAreaM2                          0
# ConstructionYear                        0
# BuildingStructure                       0
# CurrentUsage                            0
# FutureUsePurpose                   342697
# CityPlanningCategory                12089
# MaxBuildingCoverageRatioPercent         0
# MaxFloorAreaRatioPercent                0
# TransactionYear                         0
# TransactionYearQuarter                  0
# RenovationStatus                        0
# SurveyedAreaM2_Bin                      0
# dtype: int64

# %% [markdown]
# Checking if there is relation with FloorPlan and FutureUsagePurpose.

# %%
# Contingency table
contingency_table = pd.crosstab(df['FutureUsePurpose'].fillna('Missing'), df['FloorPlan'])
# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 99910.70499384074, p-value: 0.0

# %% [markdown]
# Checking if there is relation with CurrentUsage and FutureUsePurpose.

# %%
# Contingency table
contingency_table = pd.crosstab(df['FutureUsePurpose'].fillna('Missing'), df['CurrentUsage'])
# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 147731.06830096728, p-value: 0.0

# %% [markdown]
# A chi-squared test with a chi-squared statistic of 173122.77576948635 and a p-value of 0.0 is indicating an strong association between the two categorical variables being tested. The p-value of 0.0 means that the observed relationship is highly significant and unlikely to have occurred by chance.

# %%
# Group by 'FutureUsePurpose' and find the mode of 'CurrentUsage' for each group
mode_current_usage = df.groupby('FutureUsePurpose')['CurrentUsage'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()

# Display the result
print("So this is the mode for each CurrentUsage\n ",mode_current_usage)
# Out:
# So this is the mode for each CurrentUsage
#     FutureUsePurpose CurrentUsage
# 0            House        House
# 1           Office        House
# 2            Other        House
# 3             Shop         Shop

# %% [markdown]
# Filling missing values in 'FutureUsePurpose' based on the 'CurrentUsage' mode

# %%
# Dictionary to store the mode of 'FutureUsePurpose' for each 'CurrentUsage' code
currentusage_mode_dict = df.groupby('CurrentUsage')['FutureUsePurpose'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
# Missing 'FutureUsePurpose' values
missing_future_use = df['FutureUsePurpose'].isnull()
# Filling missing values in 'FutureUsePurpose' based on the 'CurrentUsage' mode
df.loc[missing_future_use, 'FutureUsePurpose'] = df.loc[missing_future_use, 'CurrentUsage'].map(currentusage_mode_dict)
df.isnull().sum()
# Out:
# PrefectureName                         0
# NearestStation                         0
# TimeToNearestStation                   0
# TradePriceYen                          0
# FloorPlan                              0
# SurveyedAreaM2                         0
# ConstructionYear                       0
# BuildingStructure                      0
# CurrentUsage                           0
# FutureUsePurpose                       3
# CityPlanningCategory               12089
# MaxBuildingCoverageRatioPercent        0
# MaxFloorAreaRatioPercent               0
# TransactionYear                        0
# TransactionYearQuarter                 0
# RenovationStatus                       0
# SurveyedAreaM2_Bin                     0
# dtype: int64

# %%
df.head()
# Out:
#   PrefectureName NearestStation  TimeToNearestStation  TradePriceYen  \
# 0       Hokkaido   Maruyamakoen             20.000000       19000000
# 1       Hokkaido   Maruyamakoen             23.000000       14000000
# 2       Hokkaido   Maruyamakoen             25.000000       27000000
# 3       Hokkaido   Maruyamakoen             15.502451       30000000
# 4       Hokkaido   Maruyamakoen              0.000000       19000000
#
#   FloorPlan  SurveyedAreaM2  ConstructionYear BuildingStructure CurrentUsage  \
# 0      4LDK              95            1997.0                RC        House
# 1      4LDK              90            1989.0                RC        House
# 2      2LDK              80            2002.0                RC        House
# 3      4LDK             120            2002.0                RC        House
# 4      4LDK              95            1997.0                RC        House
#
#   FutureUsePurpose                               CityPlanningCategory  \
# 0            House                       Neighborhood Commercial Zone
# 1            House  Category I Exclusively Low-story Residential Zone
# 2            House                        Category I Residential Zone
# 3            House                        Category I Residential Zone
# 4            House                                                NaN
#
#    MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  TransactionYear  \
# 0                             80.0                     200.0             2018
# 1                             40.0                      80.0             2017
# 2                             60.0                     200.0             2010
# 3                             60.0                     200.0             2006
# 4                             60.0                     200.0             2011
#
#    TransactionYearQuarter RenovationStatus SurveyedAreaM2_Bin
# 0                       4          Not yet           (0, 250]
# 1                       4          Not yet           (0, 250]
# 2                       2          Not yet           (0, 250]
# 3                       3          Not yet           (0, 250]
# 4                       1          Not yet           (0, 250]

# %%
currentusage_mode_dict
# Out:
# {'Factory': 'Office',
#  'House': 'House',
#  'House, Office': 'Office',
#  'House, Office, Parking Lot, Shop': None,
#  'House, Other': 'House',
#  'House, Parking Lot': 'House',
#  'House, Shop': 'Shop',
#  'House, Shop, Other': None,
#  'House, Warehouse': 'House',
#  'Office': 'Office',
#  'Office, Parking Lot': 'Other',
#  'Office, Shop': 'Shop',
#  'Office, Warehouse': 'Office',
#  'Other': 'Other',
#  'Parking Lot': 'Other',
#  'Parking Lot, Shop': 'Other',
#  'Shop': 'Shop',
#  'Shop, Other': None,
#  'Warehouse': 'Other',
#  'Warehouse, Parking Lot': 'Other',
#  'Warehouse, Shop': 'Shop',
#  'Workshop': 'Office'}

# %%
df[df['FutureUsePurpose'].isna()]
# Out:
#               PrefectureName NearestStation  TimeToNearestStation  \
# 188627                 Tokyo         Meguro                   1.0
# 570544  Hiroshima Prefecture        Midorii                   1.0
# 577075      Kochi Prefecture   Asakura (JR)                  25.0
#
#         TradePriceYen   FloorPlan  SurveyedAreaM2  ConstructionYear  \
# 188627       24000000  Open Floor              35            1987.0
# 570544       32000000        3LDK              80            2003.0
# 577075        8000000        4LDK              70            1991.0
#
#        BuildingStructure                      CurrentUsage FutureUsePurpose  \
# 188627               SRC                       Shop, Other             None
# 570544               SRC  House, Office, Parking Lot, Shop             None
# 577075                RC                House, Shop, Other             None
#
#                CityPlanningCategory  MaxBuildingCoverageRatioPercent  \
# 188627              Commercial Zone                             80.0
# 570544              Commercial Zone                             80.0
# 577075  Category I Residential Zone                             60.0
#
#         MaxFloorAreaRatioPercent  TransactionYear  TransactionYearQuarter  \
# 188627                     700.0             2009                       2
# 570544                     400.0             2007                       1
# 577075                     200.0             2009                       3
#
#        RenovationStatus SurveyedAreaM2_Bin
# 188627          Not yet           (0, 250]
# 570544          Not yet           (0, 250]
# 577075          Not yet           (0, 250]

# %% [markdown]
# There are few few datapoints in CurrentUsage where there are no FutureUsePurpose drooping those 3 rows. And look like there is just one datapoint too.

# %%
df.dropna(subset=["FutureUsePurpose"], inplace=True)

# %% [markdown]
# Let check for CityPlanningCategory

# %%
# Contingency table
contingency_table = pd.crosstab(df['CityPlanningCategory'].fillna('Missing'), df['FloorPlan'])
# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 83336.22522348045, p-value: 0.0

# %%
# Ccontingency table
contingency_table = pd.crosstab(df['CityPlanningCategory'].fillna('Missing'), df['CurrentUsage'])
# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 7301.562045640132, p-value: 0.0

# %%
# Contingency table
contingency_table = pd.crosstab(df['CityPlanningCategory'].fillna('Missing'), df['FutureUsePurpose'])

# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 8944.78056237029, p-value: 0.0

# %%
# Contingency table
contingency_table = pd.crosstab(df['CityPlanningCategory'].fillna('Missing'), df['PrefectureName'])

# Chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)
print(f'Chi-squared: {chi2}, p-value: {p}')
# Out:
# Chi-squared: 161427.22318028024, p-value: 0.0

# %% [markdown]
# Look like there is good relation here so imputing with the mode of CityPlanningCategory for each PrefectureName.

# %%
# Group by 'PrefectureName' and findng the mode of 'CityPlanningCategory' for each group
mode_city_planning = df.groupby('PrefectureName')['CityPlanningCategory'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
print(mode_city_planning)
# Out:
#           PrefectureName                               CityPlanningCategory
# 0       Aichi Prefecture                                    Commercial Zone
# 1       Akita Prefecture                                    Commercial Zone
# 2      Aomori Prefecture                                    Commercial Zone
# 3       Chiba Prefecture  Category I Exclusively Medium-high Residential...
# 4       Ehime Prefecture                        Category I Residential Zone
# 5       Fukui Prefecture                              Quasi-industrial Zone
# 6     Fukuoka Prefecture                                    Commercial Zone
# 7   Fukushima Prefecture                                    Commercial Zone
# 8        Gifu Prefecture                                    Commercial Zone
# 9       Gunma Prefecture                                    Commercial Zone
# 10  Hiroshima Prefecture                                    Commercial Zone
# 11              Hokkaido                       Neighborhood Commercial Zone
# 12      Hyogo Prefecture  Category I Exclusively Medium-high Residential...
# 13    Ibaraki Prefecture                                    Commercial Zone
# 14   Ishikawa Prefecture                                    Commercial Zone
# 15      Iwate Prefecture                                    Commercial Zone
# 16     Kagawa Prefecture                        Category I Residential Zone
# 17  Kagoshima Prefecture                                    Commercial Zone
# 18   Kanagawa Prefecture                                    Commercial Zone
# 19      Kochi Prefecture                        Category I Residential Zone
# 20   Kumamoto Prefecture                                    Commercial Zone
# 21      Kyoto Prefecture                                    Commercial Zone
# 22        Mie Prefecture                                    Commercial Zone
# 23     Miyagi Prefecture                                    Commercial Zone
# 24   Miyazaki Prefecture                       Category II Residential Zone
# 25     Nagano Prefecture                                    Commercial Zone
# 26   Nagasaki Prefecture                                    Commercial Zone
# 27       Nara Prefecture                        Category I Residential Zone
# 28    Niigata Prefecture                                    Commercial Zone
# 29       Oita Prefecture                                    Commercial Zone
# 30    Okayama Prefecture                                    Commercial Zone
# 31    Okinawa Prefecture                                    Commercial Zone
# 32      Osaka Prefecture                                    Commercial Zone
# 33       Saga Prefecture                                    Commercial Zone
# 34    Saitama Prefecture                        Category I Residential Zone
# 35      Shiga Prefecture                                    Commercial Zone
# 36    Shimane Prefecture                        Category I Residential Zone
# 37   Shizuoka Prefecture                                    Commercial Zone
# 38    Tochigi Prefecture                                    Commercial Zone
# 39  Tokushima Prefecture                                    Commercial Zone
# 40                 Tokyo                                    Commercial Zone
# 41    Tottori Prefecture                                    Commercial Zone
# 42     Toyama Prefecture                                    Commercial Zone
# 43   Wakayama Prefecture                                    Commercial Zone
# 44   Yamagata Prefecture                                    Commercial Zone
# 45  Yamaguchi Prefecture                                    Commercial Zone
# 46  Yamanashi Prefecture                                    Commercial Zone

# %%
# Dictionary to store the mode of 'CityPlanningCategory' for each 'PrefectureName' code
prefecture_mode_dict = df.groupby('PrefectureName')['CityPlanningCategory'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None).to_dict()
# Missing 'CityPlanningCategory' values
missing_city_planning = df['CityPlanningCategory'].isnull()
# Filling missing values in 'CityPlanningCategory' based on the 'PrefectureName' mode
df.loc[missing_city_planning, 'CityPlanningCategory'] = df.loc[missing_city_planning, 'PrefectureName'].map(prefecture_mode_dict)
df.isnull().sum()
# Out:
# PrefectureName                     0
# NearestStation                     0
# TimeToNearestStation               0
# TradePriceYen                      0
# FloorPlan                          0
# SurveyedAreaM2                     0
# ConstructionYear                   0
# BuildingStructure                  0
# CurrentUsage                       0
# FutureUsePurpose                   0
# CityPlanningCategory               0
# MaxBuildingCoverageRatioPercent    0
# MaxFloorAreaRatioPercent           0
# TransactionYear                    0
# TransactionYearQuarter             0
# RenovationStatus                   0
# SurveyedAreaM2_Bin                 0
# dtype: int64

# %% [markdown]
# # Further Data Cleaning

# %%
df['CurrentUsage'].value_counts(dropna=False)
# Out:
# CurrentUsage
# House                     579198
# Office                      3224
# Shop                        2801
# Other                        640
# Parking Lot                   88
# House, Shop                   51
# Office, Shop                  50
# Warehouse                     48
# House, Office                 30
# House, Other                  15
# Factory                        6
# Warehouse, Parking Lot         3
# Warehouse, Shop                3
# House, Parking Lot             3
# Office, Warehouse              2
# Workshop                       2
# Parking Lot, Shop              2
# House, Warehouse               1
# Office, Parking Lot            1
# Name: count, dtype: int64

# %% [markdown]
# Now it will be too confusing to all such categories with very less data points for each category. So just keeping "House", "Office", "Shop", "Other"

# %%
# List of categories to keep
valid_categories = ["House", "Office", "Shop", "Other"]
# Replacing categories that are not in the list with "Other"
df['CurrentUsage'] = df['CurrentUsage'].apply(lambda x: x if pd.isna(x) or x in valid_categories else "Other")
df['CurrentUsage'].value_counts(dropna=False)
# Out:
# CurrentUsage
# House     579198
# Office      3224
# Shop        2801
# Other        945
# Name: count, dtype: int64

# %% [markdown]
# Now let us drop few columns not may not be required for analysis.

# %%
df = df.drop(columns=['SurveyedAreaM2_Bin'])

# %%
df["CityPlanningCategory"].value_counts()
# Out:
# CityPlanningCategory
# Commercial Zone                                         168113
# Category I Exclusively Medium-high Residential Zone      94135
# Category I Residential Zone                              91740
# Quasi-industrial Zone                                    67598
# Neighborhood Commercial Zone                             60040
# Category II Exclusively Medium-high Residential Zone     27572
# Category II Residential Zone                             27032
# Category I Exclusively Low-story Residential Zone        17946
# Industrial Zone                                          14984
# Quasi-residential Zone                                   11868
# Urbanization Control Area                                 3746
# Category II Exclusively Low-story Residential Zone         782
# Non-divided City Planning Area                             218
# Exclusively Industrial Zone                                211
# Outside City Planning Area                                 180
# Quasi-city Planning Area                                     3
# Name: count, dtype: int64

# %% [markdown]
# Removing Outside City Planning Area  as there is just 3 data points.

# %%
df = df[df['CityPlanningCategory'] != 'Outside City Planning Area']

# %%
df.shape
# Out:
# (585988, 16)

# %%
df.columns
# Out:
# Index(['PrefectureName', 'NearestStation', 'TimeToNearestStation',
#        'TradePriceYen', 'FloorPlan', 'SurveyedAreaM2', 'ConstructionYear',
#        'BuildingStructure', 'CurrentUsage', 'FutureUsePurpose',
#        'CityPlanningCategory', 'MaxBuildingCoverageRatioPercent',
#        'MaxFloorAreaRatioPercent', 'TransactionYear', 'TransactionYearQuarter',
#        'RenovationStatus'],
#       dtype='object')

# %% [markdown]
# Checking the datatypes again

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 585988 entries, 0 to 617809
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   PrefectureName                   585988 non-null  object
#  1   NearestStation                   585988 non-null  object
#  2   TimeToNearestStation             585988 non-null  float64
#  3   TradePriceYen                    585988 non-null  int64
#  4   FloorPlan                        585988 non-null  object
#  5   SurveyedAreaM2                   585988 non-null  int64
#  6   ConstructionYear                 585988 non-null  float64
#  7   BuildingStructure                585988 non-null  object
#  8   CurrentUsage                     585988 non-null  object
#  9   FutureUsePurpose                 585988 non-null  object
#  10  CityPlanningCategory             585988 non-null  object
#  11  MaxBuildingCoverageRatioPercent  585988 non-null  float64
#  12  MaxFloorAreaRatioPercent         585988 non-null  float64
#  13  TransactionYear                  585988 non-null  int64
#  14  TransactionYearQuarter           585988 non-null  int64
#  15  RenovationStatus                 585988 non-null  object
# dtypes: float64(4), int64(4), object(8)
# memory usage: 76.0+ MB

# %%
df.select_dtypes(["object"]).columns
# Out:
# Index(['PrefectureName', 'NearestStation', 'FloorPlan', 'BuildingStructure',
#        'CurrentUsage', 'FutureUsePurpose', 'CityPlanningCategory',
#        'RenovationStatus'],
#       dtype='object')

# %%
df["PrefectureName"].value_counts()
# Out:
# PrefectureName
# Tokyo                   173619
# Kanagawa Prefecture      84644
# Osaka Prefecture         67537
# Hyogo Prefecture         36485
# Saitama Prefecture       36284
# Chiba Prefecture         30917
# Aichi Prefecture         28685
# Fukuoka Prefecture       27357
# Hokkaido                 20121
# Kyoto Prefecture         14383
# Miyagi Prefecture         9278
# Shizuoka Prefecture       5629
# Hiroshima Prefecture      4893
# Nara Prefecture           4537
# Ibaraki Prefecture        3023
# Shiga Prefecture          2880
# Niigata Prefecture        2761
# Okayama Prefecture        2230
# Oita Prefecture           2078
# Ehime Prefecture          1784
# Kumamoto Prefecture       1724
# Fukushima Prefecture      1707
# Yamaguchi Prefecture      1695
# Tochigi Prefecture        1671
# Kagawa Prefecture         1620
# Mie Prefecture            1580
# Gunma Prefecture          1566
# Ishikawa Prefecture       1398
# Gifu Prefecture           1194
# Kagoshima Prefecture      1194
# Iwate Prefecture          1106
# Nagano Prefecture         1077
# Miyazaki Prefecture        970
# Nagasaki Prefecture        958
# Okinawa Prefecture         927
# Toyama Prefecture          864
# Wakayama Prefecture        714
# Akita Prefecture           688
# Aomori Prefecture          625
# Saga Prefecture            541
# Tokushima Prefecture       508
# Yamagata Prefecture        498
# Yamanashi Prefecture       493
# Tottori Prefecture         483
# Fukui Prefecture           480
# Kochi Prefecture           321
# Shimane Prefecture         261
# Name: count, dtype: int64

# %% [markdown]
# Here I am just keeping the prefecture name and deleting the prefecture from it for clarity.

# %%
# Splitting the 'PrefectureName' column and keeping just the first part
df['PrefectureName'] = df['PrefectureName'].str.split().str[0]
df.sample(5)
# Out:
#        PrefectureName      NearestStation  TimeToNearestStation  \
# 196103          Tokyo          Shimoigusa                   6.0
# 580455        Fukuoka         Wajiro (JR)                  11.0
# 474061          Osaka               Esaka                   9.0
# 426660          Aichi  Marunouchi (Aichi)                   4.0
# 243881          Tokyo           Fujimidai                   4.0
#
#         TradePriceYen FloorPlan  SurveyedAreaM2  ConstructionYear  \
# 196103       41000000      3LDK              65            2000.0
# 580455       12000000      4LDK              70            1992.0
# 474061       20000000      3LDK              65            1979.0
# 426660        4000000       1DK              15            1989.0
# 243881       48000000      4LDK              80            1999.0
#
#        BuildingStructure CurrentUsage FutureUsePurpose  \
# 196103                RC        House            House
# 580455                RC        House            House
# 474061               SRC        House            House
# 426660               SRC        House            House
# 243881               SRC        House            House
#
#                                      CityPlanningCategory  \
# 196103  Category I Exclusively Low-story Residential Zone
# 580455                        Category I Residential Zone
# 474061                                    Commercial Zone
# 426660                                    Commercial Zone
# 243881                              Quasi-industrial Zone
#
#         MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 196103                             50.0                     150.0
# 580455                             60.0                     200.0
# 474061                             80.0                     600.0
# 426660                             80.0                     500.0
# 243881                             60.0                     200.0
#
#         TransactionYear  TransactionYearQuarter RenovationStatus
# 196103             2015                       3          Not yet
# 580455             2018                       3          Not yet
# 474061             2018                       1             Done
# 426660             2008                       4          Not yet
# 243881             2011                       1             Done

# %%
df["PrefectureName"].value_counts()
# Out:
# PrefectureName
# Tokyo        173619
# Kanagawa      84644
# Osaka         67537
# Hyogo         36485
# Saitama       36284
# Chiba         30917
# Aichi         28685
# Fukuoka       27357
# Hokkaido      20121
# Kyoto         14383
# Miyagi         9278
# Shizuoka       5629
# Hiroshima      4893
# Nara           4537
# Ibaraki        3023
# Shiga          2880
# Niigata        2761
# Okayama        2230
# Oita           2078
# Ehime          1784
# Kumamoto       1724
# Fukushima      1707
# Yamaguchi      1695
# Tochigi        1671
# Kagawa         1620
# Mie            1580
# Gunma          1566
# Ishikawa       1398
# Gifu           1194
# Kagoshima      1194
# Iwate          1106
# Nagano         1077
# Miyazaki        970
# Nagasaki        958
# Okinawa         927
# Toyama          864
# Wakayama        714
# Akita           688
# Aomori          625
# Saga            541
# Tokushima       508
# Yamagata        498
# Yamanashi       493
# Tottori         483
# Fukui           480
# Kochi           321
# Shimane         261
# Name: count, dtype: int64

# %%
df["BuildingStructure"].value_counts()
# Out:
# BuildingStructure
# RC            405171
# SRC           175803
# S               3893
# SRC, RC          616
# RC, S            256
# SRC, S           137
# W                 71
# B                 20
# LS                17
# SRC, RC, S         2
# RC, B              1
# RC, W              1
# Name: count, dtype: int64

# %%
#List of less frequent values to be replaced with "Other"
less_frequent_values = ['W', 'B', 'LS', 'RC, B', 'RC, W', 'SRC, RC, S']
# Replace less frequent values in the 'BuildingStructure' column with "Other"
df['BuildingStructure'] = df['BuildingStructure'].apply(lambda x: 'Other' if x in less_frequent_values else x)
df["BuildingStructure"].value_counts()
# Out:
# BuildingStructure
# RC         405171
# SRC        175803
# S            3893
# SRC, RC       616
# RC, S         256
# SRC, S        137
# Other         112
# Name: count, dtype: int64

# %%
df["CurrentUsage"].value_counts()
# Out:
# CurrentUsage
# House     579019
# Office      3223
# Shop        2801
# Other        945
# Name: count, dtype: int64

# %%
df["FloorPlan"].value_counts()
# Out:
# FloorPlan
# 3LDK                270989
# 2LDK                 84222
# 1K                   82597
# 4LDK                 54430
# 1LDK                 24539
# 2DK                  18994
# 1DK                  17177
# 3DK                  11279
# 1R                    6340
# Open Floor            4671
# 2LDK+S                3538
# 4DK                   1602
# 2K                    1148
# 1LDK+S                 999
# 3LDK+S                 846
# 5LDK                   776
# 3K                     440
# 2DK+S                  421
# 4LDK+S                 151
# 4K                     147
# 3LK                    102
# 5DK                     90
# Studio Apartment        77
# 1DK+S                   72
# 3DK+S                   68
# 6LDK                    30
# Duplex                  27
# 5LDK+S                  25
# 4DK+S                   22
# 2LK                     21
# 1K+S                    18
# 1R+S                    16
# 1LK                     12
# 2K+S                    11
# 3LD                     10
# 2LD+S                    8
# 1L                       8
# 4L+K                     8
# 3LD+S                    5
# 3LDK+K                   5
# 7LDK                     5
# 6DK                      4
# 2LK+S                    4
# 6LDK+S                   3
# 3K+S                     3
# 1LD+S                    3
# 5K                       3
# 4LDK+K                   3
# 3D                       2
# 2L                       2
# 7LDK+S                   2
# 8LDK                     2
# 5LDK+K                   1
# 2L+S                     1
# 4L                       1
# 8LDK+S                   1
# 2D                       1
# 2LDK+K                   1
# 4D                       1
# 1L+S                     1
# 1DK+K                    1
# 2LD                      1
# 7DK                      1
# Name: count, dtype: int64

# %%
#List of less frequent values to be replaced with "Other"
less_frequent_values = ['3LK', '5DK', 'Studio Apartment', '3DK+S', '1DK+S', '6LDK', 'Duplex', '5LDK+S', '4DK+S', '2LK', '1K+S', '1R+S', '1LK', '2K+S', '3LD', '1L', '2LD+S', '4L+K', '3LDK+K', '3LD+S', '2LK+S', '7LDK', '6DK', '3K+S', '1LD+S', '4LDK+K', '8LDK', '5K', '2L', '6LDK+S', '7LDK+S', '3D', '2L+S', '4L', '8LDK+S', '2D', '5LDK+K', '2LDK+K', '1L+S', '1DK+K', '2LD', '4D', '7DK']
# Replace less frequent values in the 'FloorPlan' column with "Other"
df['FloorPlan'] = df['FloorPlan'].apply(lambda x: 'Other' if x in less_frequent_values else x)
df["FloorPlan"].value_counts()
# Out:
# FloorPlan
# 3LDK          270989
# 2LDK           84222
# 1K             82597
# 4LDK           54430
# 1LDK           24539
# 2DK            18994
# 1DK            17177
# 3DK            11279
# 1R              6340
# Open Floor      4671
# 2LDK+S          3538
# 4DK             1602
# 2K              1148
# 1LDK+S           999
# 3LDK+S           846
# 5LDK             776
# Other            682
# 3K               440
# 2DK+S            421
# 4LDK+S           151
# 4K               147
# Name: count, dtype: int64

# %%
df["NearestStation"].value_counts()
# Out:
# NearestStation
# Kawasaki           2242
# Hiroshima          1809
# Hamamatsu          1798
# Kawaguchi          1728
# Kachidoki          1717
#                    ...
# Arao (Kumamoto)       1
# Shidaiigakubu         1
# Otowacho              1
# Hikoneserikawa        1
# Haginochaya           1
# Name: count, Length: 3714, dtype: int64

# %% [markdown]
# There are 3714 unique Nearest Stations

# %% [markdown]
# Dropping NearestStation and using only the time to nearest station in my analysis.

# %%
df.drop(columns='NearestStation',inplace=True)
df.columns
# Out:
# Index(['PrefectureName', 'TimeToNearestStation', 'TradePriceYen', 'FloorPlan',
#        'SurveyedAreaM2', 'ConstructionYear', 'BuildingStructure',
#        'CurrentUsage', 'FutureUsePurpose', 'CityPlanningCategory',
#        'MaxBuildingCoverageRatioPercent', 'MaxFloorAreaRatioPercent',
#        'TransactionYear', 'TransactionYearQuarter', 'RenovationStatus'],
#       dtype='object')

# %%
cat=df.select_dtypes(["object"]).columns

# %%
#Unique values in categorical columns
for col in cat:
    print(f'{col}:{df[col].nunique()}')
# Out:
# PrefectureName:47
# FloorPlan:21
# BuildingStructure:7
# CurrentUsage:4
# FutureUsePurpose:4
# CityPlanningCategory:15
# RenovationStatus:2

# %% [markdown]
# Now these categorical columns are more workable.

# %% [markdown]
# Another addition I am making is to add another column to show the `TradePriceYEn` in Canadian Dollars so that it is easier while plotting charts

# %%
# Exchange rate
exchange_rate = 0.0093

# Updating TradePriceYen with TradePriceCAD values
df['TradePriceCAD'] = df['TradePriceYen'] * exchange_rate
df
# Out:
#        PrefectureName  TimeToNearestStation  TradePriceYen FloorPlan  \
# 0            Hokkaido             20.000000       19000000      4LDK
# 1            Hokkaido             23.000000       14000000      4LDK
# 2            Hokkaido             25.000000       27000000      2LDK
# 3            Hokkaido             15.502451       30000000      4LDK
# 4            Hokkaido              0.000000       19000000      4LDK
# ...               ...                   ...            ...       ...
# 617803        Okinawa              7.000000        5000000      1LDK
# 617804        Okinawa              8.000000       11000000    2LDK+S
# 617805        Okinawa              6.000000        5800000      2LDK
# 617806        Okinawa              4.000000       16000000      3LDK
# 617809        Okinawa              8.000000        6000000      3LDK
#
#         SurveyedAreaM2  ConstructionYear BuildingStructure CurrentUsage  \
# 0                   95            1997.0                RC        House
# 1                   90            1989.0                RC        House
# 2                   80            2002.0                RC        House
# 3                  120            2002.0                RC        House
# 4                   95            1997.0                RC        House
# ...                ...               ...               ...          ...
# 617803              45            1985.0                RC        House
# 617804              60            1985.0                RC        House
# 617805              50            1985.0                RC        House
# 617806              65            1999.0                RC        House
# 617809              70            1989.0                RC        House
#
#        FutureUsePurpose                               CityPlanningCategory  \
# 0                 House                       Neighborhood Commercial Zone
# 1                 House  Category I Exclusively Low-story Residential Zone
# 2                 House                        Category I Residential Zone
# 3                 House                        Category I Residential Zone
# 4                 House                       Neighborhood Commercial Zone
# ...                 ...                                                ...
# 617803            House                                    Commercial Zone
# 617804            House                                    Commercial Zone
# 617805            House                                    Commercial Zone
# 617806            House                                    Commercial Zone
# 617809            House  Category I Exclusively Medium-high Residential...
#
#         MaxBuildingCoverageRatioPercent  MaxFloorAreaRatioPercent  \
# 0                                  80.0                     200.0
# 1                                  40.0                      80.0
# 2                                  60.0                     200.0
# 3                                  60.0                     200.0
# 4                                  60.0                     200.0
# ...                                 ...                       ...
# 617803                             80.0                     400.0
# 617804                             80.0                     600.0
# 617805                             80.0                     400.0
# 617806                             80.0                     400.0
# 617809                             60.0                     200.0
#
#         TransactionYear  TransactionYearQuarter RenovationStatus  \
# 0                  2018                       4          Not yet
# 1                  2017                       4          Not yet
# 2                  2010                       2          Not yet
# 3                  2006                       3          Not yet
# 4                  2011                       1          Not yet
# ...                 ...                     ...              ...
# 617803             2008                       4          Not yet
# 617804             2007                       3          Not yet
# 617805             2007                       2          Not yet
# 617806             2008                       3             Done
# 617809             2007                       3          Not yet
#
#         TradePriceCAD
# 0            176700.0
# 1            130200.0
# 2            251100.0
# 3            279000.0
# 4            176700.0
# ...               ...
# 617803        46500.0
# 617804       102300.0
# 617805        53940.0
# 617806       148800.0
# 617809        55800.0
#
# [585988 rows x 16 columns]

# %% [markdown]
# # Analyzing Patterns

# %% [markdown]
# Let us look at certain patterns with in our Data. For now looking at the various distributions of variables and their count

# %%
df.select_dtypes(["float", "int"]).columns
# Out:
# Index(['TimeToNearestStation', 'TradePriceYen', 'SurveyedAreaM2',
#        'ConstructionYear', 'MaxBuildingCoverageRatioPercent',
#        'MaxFloorAreaRatioPercent', 'TransactionYear', 'TransactionYearQuarter',
#        'TradePriceCAD'],
#       dtype='object')

# %%
df.select_dtypes(["object"]).columns
# Out:
# Index(['PrefectureName', 'FloorPlan', 'BuildingStructure', 'CurrentUsage',
#        'FutureUsePurpose', 'CityPlanningCategory', 'RenovationStatus'],
#       dtype='object')

# %%
numeric_cols=['TimeToNearestStation', 'TradePriceYen', 'SurveyedAreaM2',
       'ConstructionYear',
       'MaxBuildingCoverageRatioPercent', 'MaxFloorAreaRatioPercent',
       'TransactionYear', 'TransactionYearQuarter','TradePriceCAD']

# %%
categorical_cols =['PrefectureName', 'FloorPlan', 'BuildingStructure', 'CurrentUsage',
       'FutureUsePurpose', 'CityPlanningCategory', 'RenovationStatus']

# %%
plt.figure(figsize=(10, 6))
for col in numeric_cols:
    sns.histplot(data=df, x=col, kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# **Analysis:**
# 1. Looks like most of the condos take around 30 minutes to the nearest station and there is a spike at 1hr to nearest station,also for 1 1/2 hrs and 3 hrs.
# 2. There is definitely a right skew in this distribution .There are less expensive houses.
# 3. Most of the condos have an area below 250m2
# 4. Construction year of condos ranges from 1965 to 2019 and with the highest being at just before and after 2000.
# 5. MaxBuildingRatioPercent looks like there are only peaks at 40,50,60 and 80 with 60 being the highest.
# 6. MaxFloorAreaRatioPercent  mostly falls below 800 and spikes at 200.
# 7. Most no of condos were bought in 2016 and lowest in 2005
# 8. Quaterly dstribution of Transactions look  almost uniform

# %%
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")
    ax = sns.countplot(data=df, x=col, order=df[col].value_counts().index,color='#A0D468')
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    
    # Adding count labels above the bars
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points', rotation=45)
    
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# **Analysis:**
# 1. Highest number of units are in Tokyo and lowest in Shimane prefecture
# 2. As you can see from the plot most of the structures are 3LDK.2LDK,1K,4LDK,1LDK,2Dk are other most popular floor plans.
# 3. Most of the units has a Reinforced Concrete structure.
# 4. Most of the units are currenty used as houses.
# 5. Here most of the units are to be used as houses with very few as Office, shops, and others.
# 5. Most of the units are in Commercial Zone areas and with least being in Quasi-city Planning Area
# 6. Most of the units are not renovated.

# %%
numerical_cols=['TimeToNearestStation', 'SurveyedAreaM2',
       'ConstructionYear',
       'MaxBuildingCoverageRatioPercent', 'MaxFloorAreaRatioPercent',
       'TransactionYear', 'TransactionYearQuarter','TradePriceCAD']

# %%
num_cols=numerical_cols=['ConstructionYear','TransactionYear', 'TransactionYearQuarter']

# %%
# Iterate through numerical columns
for col in num_cols:
    # Histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, y='TradePriceCAD', bins=30, kde=True)
    plt.title(f'Histogram of {col} with Trade Price in Canadian Dollars')
    plt.xlabel(col)
    plt.ylabel('Trade Price (CAD)')
    plt.grid(True)
    plt.show()

# %%
numeri_cols=['TimeToNearestStation', 'SurveyedAreaM2'
       'MaxBuildingCoverageRatioPercent', 'MaxFloorAreaRatioPercent','TradePriceCAD']

# %%
# Defining a function to format tick labels with full numbers
def format_func(value, tick_number):
    return f'{int(value):,}'
for col in numerical_cols[:-1]:
    plt.figure(figsize=(10, 6))
    sns.jointplot(x=col, y='TradePriceCAD', data=df, kind='hex', gridsize=20)
    ax = plt.gca()
    ax.yaxis.set_major_formatter(FuncFormatter(format_func))
    plt.grid(True)
    plt.title(f'Hexbin Plot of {col} vs. Trade Price in Canadian Dollars')
    plt.xlabel(col)
    plt.ylabel('Trade Price (CAD)')
    plt.show()

# %% [markdown]
# These scatter plots are to look at the distribution of the TradePriceCAD with the numerical columns.

# %%
# Defining a function to format tick labels with full numbers
def format_func(value, tick_number):
    return f'{int(value):,}'  # This formats the label as an integer with commas
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')    
    # Formatting the y-axis tick labels with full numbers
    ax = plt.gca()
    ax.yaxis.set_major_formatter(FuncFormatter(format_func))    
    plt.grid(True)  # Add gridlines to the plot    
    plt.title(f'Bar Plot of {col} vs. Trade Price')
    plt.xlabel(col)
    plt.ylabel('Mean Trade Price (Yen)')
    plt.xticks(rotation=90)
    #plt.savefig(f'scatter_plot_{col}_vs_trade_price.png', bbox_inches='tight')
    plt.show()
# Out:
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')
# C:\Users\Thekku\AppData\Local\Temp\ipykernel_26952\3563564305.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x=col, y='TradePriceYen', ci=None,color='#A0D468')

# %% [markdown]
# **Analysis:**
#
# 1. As expected Tokyo has the highest prices.
# 2. The most expensive are 2LDK+S floor plan.
# 2. Looks like the most expensive are are in reinforced concrete + Steel category.
# 3. Current Usage Houses and shops are almost the same.
# 4. Incase of future use mostly everything comes to the same range.
# 5. Quasi -city planning area has the most expensive prices but from one of the previous plots we saw that it is the least sold. This clearly explains why they are sold less. Outside city planning area has the cheapest prices.
# 6. Surprisingly there isn't much difference in the prices.

# %% [markdown]
# Now to create a correlation matrix let us check the unique values in the columns

# %% [markdown]
# Let us create a heatmap for all the correlations

# %%
df.drop(columns='TradePriceCAD',inplace=True)
df.columns
# Out:
# Index(['PrefectureName', 'TimeToNearestStation', 'TradePriceYen', 'FloorPlan',
#        'SurveyedAreaM2', 'ConstructionYear', 'BuildingStructure',
#        'CurrentUsage', 'FutureUsePurpose', 'CityPlanningCategory',
#        'MaxBuildingCoverageRatioPercent', 'MaxFloorAreaRatioPercent',
#        'TransactionYear', 'TransactionYearQuarter', 'RenovationStatus'],
#       dtype='object')

# %%
#Converting categorical columns to dummy variables
df_dummies = pd.get_dummies(df, columns=categorical_cols,drop_first=True)
df_dummies.head()
# Correlation matrix
correlation_matrix = df_dummies.corr()
# Diagonal creation
diagonal_corr_matrix = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
diagonal_corr_matrix = diagonal_corr_matrix.fillna(0)
# Print the diagonal correlation matrix
#print(diagonal_corr_matrix)
# Heatmap
plt.figure(figsize=(20, 10))
mask = np.triu(np.ones_like(diagonal_corr_matrix, dtype=bool))
sns.heatmap(diagonal_corr_matrix, annot=False, cmap='coolwarm', cbar=True, mask=~mask)
plt.show()
#plt.savefig(f'Correlation matrix.png', bbox_inches='tight')
plt.show()

# %%
df_dummies.columns
# Out:
# Index(['TimeToNearestStation', 'TradePriceYen', 'SurveyedAreaM2',
#        'ConstructionYear', 'MaxBuildingCoverageRatioPercent',
#        'MaxFloorAreaRatioPercent', 'TransactionYear', 'TransactionYearQuarter',
#        'PrefectureName_Akita', 'PrefectureName_Aomori',
#        ...
#        'CityPlanningCategory_Commercial Zone',
#        'CityPlanningCategory_Exclusively Industrial Zone',
#        'CityPlanningCategory_Industrial Zone',
#        'CityPlanningCategory_Neighborhood Commercial Zone',
#        'CityPlanningCategory_Non-divided City Planning Area',
#        'CityPlanningCategory_Quasi-city Planning Area',
#        'CityPlanningCategory_Quasi-industrial Zone',
#        'CityPlanningCategory_Quasi-residential Zone',
#        'CityPlanningCategory_Urbanization Control Area',
#        'RenovationStatus_Not yet'],
#       dtype='object', length=101)

# %% [markdown]
# Shows a distribution of the numerical columns

# %%
df_dummies.shape
# Out:
# (585988, 101)

# %%
import os
data_folder = 'data'
# Save the DataFrame to a CSV file in the 'data/dummies' folder
df_dummies.to_csv(os.path.join(data_folder, 'dummies.csv'), index=False)

# %% [markdown]
# # Summary

# %% [markdown]
# In this Jupyter notebook, I conducted a analysis of a real estate dataset focused on Japan pre-owned condos and other categories. The analysis included data cleaning, transformation, and visualization. I explored the impact of various features, such as property type and construction year, on real estate prices. The analysis culminated in visualizations and insights aimed at understanding the real estate market in Japan, with a focus on trade prices.
#
# Further basic modelling is done in PartIII_Basic_Modelling.ipynb notebbok
